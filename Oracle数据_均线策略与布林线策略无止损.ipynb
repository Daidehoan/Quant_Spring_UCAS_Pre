# %% [markdown]
# 使用茅台数据：
# 1，格兰威尔法则策略
# 2，布林线策略
# 3，变点检验（策略的切换）

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import numpy as np
import pymannkendall as mk

# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),('trend_test_period', 20), ("period", 20), ("devfactor", 0.5), ("debug", False), ("size", 1),
        ("trail", False), ("stop_loss", 0.02)
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.data_trend_test = self.datas[0].get(size=self.p.trend_test_period)  # ago defaults to 0
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        #设置变点检验的区间
        #初始化布林线
        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)
        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f, Size %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f, Size %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm,
                          order.executed.size))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        print(self.position)
        #进行趋势检验
        self.trend_test_data = self.data.get(size=self.params.trend_test_period)
        trend, h, p, z, Tau, s, var_s, slope, intercept = mk.original_test(self.trend_test_data)
        print(trend)
        #没有趋势时，用布林线法则
        if trend == 'no trend':
            print('没有趋势,使用布林线法则')
            #已经是多头的情形
            if self.position.size > 0:
                if self.data.close < self.boll.lines.bot:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                else:
                    self.log('close long, %.2f' % self.dataclose[0])
                    self.order = self.close()
            #已经是空头的情形
            if self.position.size < 0:
                if self.data.close > self.boll.lines.top:
                    self.log('SELL CREATE, %.2f' % self.dataclose[0])
                    self.order = self.sell() 
                else:
                    self.log('close short, %.2f' % self.dataclose[0])
                    self.order = self.close()
            #还没有持仓的情形
            if self.position.size == 0:
                if self.data.close > self.boll.lines.top:
                    self.log('SELL CREATE, %.2f' % self.dataclose[0])
                    self.order = self.sell() 
                else:
                    self.log('close short, %.2f' % self.dataclose[0])
                    self.order = self.buy()
        else:  
            print('有趋势,使用均线法则')
            if self.order:
                return
            #已经是多头的情形
            if self.position.size > 0:
                if self.dataclose[0] > self.sma[0]:
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                if self.dataclose[0] > self.sma[0]:
                    self.log('close long, %.2f' % self.dataclose[0])
                    self.order = self.close()
            #已经是空头的情形
            if self.position.size < 0:
                if self.dataclose[0] > self.sma[0]:
                    self.log('close short, %.2f' % self.dataclose[0])
                    self.order = self.close()
                if self.dataclose[0] < self.sma[0]:
                    self.log('SELL CREATE, %.2f' % self.dataclose[0])
                    self.order = self.sell()
            #还没有持仓的情形
            if self.position.size == 0:
                if self.dataclose[0] > self.sma[0]:
                    self.log('close short, %.2f' % self.dataclose[0])
                    self.order = self.buy()
                if self.dataclose[0] < self.sma[0]:
                    self.log('SELL CREATE, %.2f' % self.dataclose[0])
                    self.order = self.sell()

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[1]))
    datapath = os.path.join(modpath, 'D:\desktop\orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2007, 1, 1),
        # Do not pass values before this date
        todate=datetime.datetime(2008, 1, 1),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.plot(style='candlestick')
# Out:
# Starting Portfolio Value: 1000.00
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-01-31, SELL CREATE, 15.26
# 2007-02-01, SELL EXECUTED, Price: 15.32, Cost: -153.20, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 15.32
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.17
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-01, SELL CREATE, 15.17
# 2007-02-02, SELL EXECUTED, Price: 15.25, Cost: -152.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 15.285
# - Price orig: 15.32
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.49
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-02, close short, 15.49
# 2007-02-05, BUY EXECUTED, Price: 15.43, Cost: -305.70, Comm 0.00, Size 20.00
# 2007-02-05, OPERATION PROFIT, GROSS -2.90, NET -2.90
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 15.285
# - Closed: 20
# - Opened: 0
# - Adjbase: 15.49
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-05, SELL CREATE, 15.26
# 2007-02-06, SELL EXECUTED, Price: 15.24, Cost: -152.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 15.24
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.14
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-06, SELL CREATE, 15.14
# 2007-02-07, SELL EXECUTED, Price: 15.23, Cost: -152.30, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 15.235000000000003
# - Price orig: 15.24
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.04
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-07, SELL CREATE, 15.04
# 2007-02-08, SELL EXECUTED, Price: 15.01, Cost: -150.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 15.160000000000002
# - Price orig: 15.235000000000003
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.86
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-08, SELL CREATE, 14.86
# 2007-02-09, SELL EXECUTED, Price: 14.93, Cost: -149.30, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -40
# - Price: 15.102500000000003
# - Price orig: 15.160000000000002
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.85
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-09, SELL CREATE, 14.85
# 2007-02-12, SELL EXECUTED, Price: 14.81, Cost: -148.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -50
# - Price: 15.044000000000004
# - Price orig: 15.102500000000003
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.81
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-12, SELL CREATE, 14.81
# 2007-02-13, SELL EXECUTED, Price: 14.86, Cost: -148.60, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -60
# - Price: 15.013333333333337
# - Price orig: 15.044000000000004
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.78
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-13, SELL CREATE, 14.78
# 2007-02-14, SELL EXECUTED, Price: 14.89, Cost: -148.90, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -70
# - Price: 14.995714285714289
# - Price orig: 15.013333333333337
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.92
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-14, SELL CREATE, 14.92
# 2007-02-15, SELL EXECUTED, Price: 14.98, Cost: -149.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -80
# - Price: 14.993750000000002
# - Price orig: 14.995714285714289
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.04
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-15, SELL CREATE, 15.04
# 2007-02-16, SELL EXECUTED, Price: 15.02, Cost: -150.20, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -90
# - Price: 14.99666666666667
# - Price orig: 14.993750000000002
# - Closed: 0
# - Opened: -10
# - Adjbase: 14.85
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-16, SELL CREATE, 14.85
# 2007-02-20, SELL EXECUTED, Price: 14.85, Cost: -148.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -100
# - Price: 14.982000000000003
# - Price orig: 14.99666666666667
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.1
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-20, close short, 15.10
# 2007-02-21, BUY EXECUTED, Price: 15.09, Cost: -1498.20, Comm 0.00, Size 100.00
# 2007-02-21, OPERATION PROFIT, GROSS -10.80, NET -10.80
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.982000000000003
# - Closed: 100
# - Opened: 0
# - Adjbase: 15.1
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-02-21, close short, 15.30
# 2007-02-22, BUY EXECUTED, Price: 15.35, Cost: 153.50, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 15.35
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 15.36
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-02-22, close long, 15.36
# 2007-02-23, SELL EXECUTED, Price: 15.33, Cost: 153.50, Comm 0.00, Size -10.00
# 2007-02-23, OPERATION PROFIT, GROSS -0.20, NET -0.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 15.35
# - Closed: -10
# - Opened: 0
# - Adjbase: 15.36
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-02-23, close short, 14.96
# 2007-02-26, BUY EXECUTED, Price: 15.04, Cost: 150.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 15.04
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.96
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-02-26, BUY CREATE, 14.96
# 2007-02-27, BUY EXECUTED, Price: 14.81, Cost: 148.10, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 14.925
# - Price orig: 15.04
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.49
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-02-27, BUY CREATE, 14.49
# 2007-02-28, BUY EXECUTED, Price: 14.56, Cost: 145.60, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 30
# - Price: 14.803333333333335
# - Price orig: 14.925
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.61
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 30
# - Price: 14.803333333333335
# - Price orig: 14.925
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.92
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-01, close long, 14.92
# 2007-03-02, SELL EXECUTED, Price: 14.79, Cost: 444.10, Comm 0.00, Size -30.00
# 2007-03-02, OPERATION PROFIT, GROSS -0.40, NET -0.40
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.803333333333335
# - Closed: -30
# - Opened: 0
# - Adjbase: 14.92
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-02, close short, 14.86
# 2007-03-05, BUY EXECUTED, Price: 14.69, Cost: 146.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 14.69
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.56
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-05, BUY CREATE, 14.56
# 2007-03-06, BUY EXECUTED, Price: 14.69, Cost: 146.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 14.690000000000001
# - Price orig: 14.69
# - Closed: 0
# - Opened: 10
# - Adjbase: 15.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-06, close long, 15.01
# 2007-03-07, SELL EXECUTED, Price: 14.92, Cost: 293.80, Comm 0.00, Size -20.00
# 2007-03-07, OPERATION PROFIT, GROSS 4.60, NET 4.60
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.690000000000001
# - Closed: -20
# - Opened: 0
# - Adjbase: 15.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-07, close short, 14.67
# 2007-03-08, BUY EXECUTED, Price: 14.85, Cost: 148.50, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 14.85
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.85
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-08, close long, 14.85
# 2007-03-09, SELL EXECUTED, Price: 14.95, Cost: 148.50, Comm 0.00, Size -10.00
# 2007-03-09, OPERATION PROFIT, GROSS 1.00, NET 1.00
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.85
# - Closed: -10
# - Opened: 0
# - Adjbase: 14.85
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-09, close short, 14.79
# 2007-03-12, BUY EXECUTED, Price: 14.77, Cost: 147.70, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 14.77
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 15.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-12, close long, 15.18
# 2007-03-13, SELL EXECUTED, Price: 15.06, Cost: 147.70, Comm 0.00, Size -10.00
# 2007-03-13, OPERATION PROFIT, GROSS 2.90, NET 2.90
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.77
# - Closed: -10
# - Opened: 0
# - Adjbase: 15.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-13, close short, 14.81
# 2007-03-14, BUY EXECUTED, Price: 14.89, Cost: 148.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 14.89
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 15.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-14, close long, 15.01
# 2007-03-15, SELL EXECUTED, Price: 14.99, Cost: 148.90, Comm 0.00, Size -10.00
# 2007-03-15, OPERATION PROFIT, GROSS 1.00, NET 1.00
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.89
# - Closed: -10
# - Opened: 0
# - Adjbase: 15.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-15, close short, 14.87
# 2007-03-16, BUY EXECUTED, Price: 14.86, Cost: 148.60, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 14.86
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 14.85
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-16, close long, 14.85
# 2007-03-19, SELL EXECUTED, Price: 14.97, Cost: 148.60, Comm 0.00, Size -10.00
# 2007-03-19, OPERATION PROFIT, GROSS 1.10, NET 1.10
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 14.86
# - Closed: -10
# - Opened: 0
# - Adjbase: 14.85
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-19, SELL CREATE, 15.28
# 2007-03-20, SELL EXECUTED, Price: 15.34, Cost: -153.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 15.34
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 15.61
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-20, SELL CREATE, 15.61
# 2007-03-21, SELL EXECUTED, Price: 16.29, Cost: -162.90, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 15.814999999999998
# - Price orig: 15.34
# - Closed: 0
# - Opened: -10
# - Adjbase: 16.16
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-03-21, SELL CREATE, 16.16
# 2007-03-22, SELL EXECUTED, Price: 16.02, Cost: -160.20, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 15.883333333333331
# - Price orig: 15.814999999999998
# - Closed: 0
# - Opened: -10
# - Adjbase: 16.45
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-22, close short, 16.45
# 2007-03-23, BUY EXECUTED, Price: 16.42, Cost: -476.50, Comm 0.00, Size 30.00
# 2007-03-23, OPERATION PROFIT, GROSS -16.10, NET -16.10
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 15.883333333333331
# - Closed: 30
# - Opened: 0
# - Adjbase: 16.45
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-23, close short, 16.22
# 2007-03-26, BUY EXECUTED, Price: 16.21, Cost: 162.10, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 16.21
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 16.36
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-26, BUY CREATE, 16.36
# 2007-03-26, close long, 16.36
# 2007-03-27, BUY EXECUTED, Price: 16.32, Cost: 163.20, Comm 0.00, Size 10.00
# 2007-03-27, SELL EXECUTED, Price: 16.32, Cost: 162.65, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.265
# - Price orig: 16.265
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.45
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-27, BUY CREATE, 16.45
# 2007-03-27, close long, 16.45
# 2007-03-28, BUY EXECUTED, Price: 16.31, Cost: 163.10, Comm 0.00, Size 10.00
# 2007-03-28, SELL EXECUTED, Price: 16.31, Cost: 162.88, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.2875
# - Price orig: 16.2875
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.16
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-28, BUY CREATE, 16.16
# 2007-03-28, close long, 16.16
# 2007-03-29, BUY EXECUTED, Price: 16.30, Cost: 163.00, Comm 0.00, Size 10.00
# 2007-03-29, SELL EXECUTED, Price: 16.30, Cost: 162.94, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.29375
# - Price orig: 16.29375
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-29, BUY CREATE, 16.15
# 2007-03-29, close long, 16.15
# 2007-03-30, BUY EXECUTED, Price: 16.17, Cost: 161.70, Comm 0.00, Size 10.00
# 2007-03-30, SELL EXECUTED, Price: 16.17, Cost: 162.32, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.231875000000002
# - Price orig: 16.231875000000002
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.13
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-03-30, BUY CREATE, 16.13
# 2007-03-30, close long, 16.13
# 2007-04-02, BUY EXECUTED, Price: 16.08, Cost: 160.80, Comm 0.00, Size 10.00
# 2007-04-02, SELL EXECUTED, Price: 16.08, Cost: 161.56, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.1559375
# - Price orig: 16.1559375
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.14
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-02, BUY CREATE, 16.14
# 2007-04-02, close long, 16.14
# 2007-04-03, BUY EXECUTED, Price: 16.22, Cost: 162.20, Comm 0.00, Size 10.00
# 2007-04-03, SELL EXECUTED, Price: 16.22, Cost: 161.88, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.18796875
# - Price orig: 16.18796875
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.33
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-03, BUY CREATE, 16.33
# 2007-04-03, close long, 16.33
# 2007-04-04, BUY EXECUTED, Price: 16.32, Cost: 163.20, Comm 0.00, Size 10.00
# 2007-04-04, SELL EXECUTED, Price: 16.32, Cost: 162.54, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.253984374999998
# - Price orig: 16.253984374999998
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.51
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-04, BUY CREATE, 16.51
# 2007-04-04, close long, 16.51
# 2007-04-05, BUY EXECUTED, Price: 16.46, Cost: 164.60, Comm 0.00, Size 10.00
# 2007-04-05, SELL EXECUTED, Price: 16.46, Cost: 163.57, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.3569921875
# - Price orig: 16.3569921875
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.61
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-05, BUY CREATE, 16.61
# 2007-04-05, close long, 16.61
# 2007-04-09, BUY EXECUTED, Price: 16.60, Cost: 166.00, Comm 0.00, Size 10.00
# 2007-04-09, SELL EXECUTED, Price: 16.60, Cost: 164.78, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.47849609375
# - Price orig: 16.47849609375
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.52
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-09, BUY CREATE, 16.52
# 2007-04-09, close long, 16.52
# 2007-04-10, BUY EXECUTED, Price: 16.70, Cost: 167.00, Comm 0.00, Size 10.00
# 2007-04-10, SELL EXECUTED, Price: 16.70, Cost: 165.89, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.589248046875
# - Price orig: 16.589248046875
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.77
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-10, BUY CREATE, 16.77
# 2007-04-10, close long, 16.77
# 2007-04-11, BUY EXECUTED, Price: 16.81, Cost: 168.10, Comm 0.00, Size 10.00
# 2007-04-11, SELL EXECUTED, Price: 16.81, Cost: 167.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.6996240234375
# - Price orig: 16.6996240234375
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.54
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-11, BUY CREATE, 16.54
# 2007-04-11, close long, 16.54
# 2007-04-12, BUY EXECUTED, Price: 16.52, Cost: 165.20, Comm 0.00, Size 10.00
# 2007-04-12, SELL EXECUTED, Price: 16.52, Cost: 166.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.609812011718752
# - Price orig: 16.609812011718752
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.63
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-12, BUY CREATE, 16.63
# 2007-04-12, close long, 16.63
# 2007-04-13, BUY EXECUTED, Price: 16.71, Cost: 167.10, Comm 0.00, Size 10.00
# 2007-04-13, SELL EXECUTED, Price: 16.71, Cost: 166.60, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.659906005859376
# - Price orig: 16.659906005859376
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.57
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-13, BUY CREATE, 16.57
# 2007-04-13, close long, 16.57
# 2007-04-16, BUY EXECUTED, Price: 16.62, Cost: 166.20, Comm 0.00, Size 10.00
# 2007-04-16, SELL EXECUTED, Price: 16.62, Cost: 166.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.63995300292969
# - Price orig: 16.63995300292969
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-16, BUY CREATE, 16.81
# 2007-04-16, close long, 16.81
# 2007-04-17, BUY EXECUTED, Price: 16.72, Cost: 167.20, Comm 0.00, Size 10.00
# 2007-04-17, SELL EXECUTED, Price: 16.72, Cost: 166.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.679976501464843
# - Price orig: 16.679976501464843
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.8
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-17, BUY CREATE, 16.80
# 2007-04-17, close long, 16.80
# 2007-04-18, BUY EXECUTED, Price: 16.72, Cost: 167.20, Comm 0.00, Size 10.00
# 2007-04-18, SELL EXECUTED, Price: 16.72, Cost: 167.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.69998825073242
# - Price orig: 16.69998825073242
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-18, BUY CREATE, 16.66
# 2007-04-18, close long, 16.66
# 2007-04-19, BUY EXECUTED, Price: 16.50, Cost: 165.00, Comm 0.00, Size 10.00
# 2007-04-19, SELL EXECUTED, Price: 16.50, Cost: 166.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.59999412536621
# - Price orig: 16.59999412536621
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.69
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-19, BUY CREATE, 16.69
# 2007-04-19, close long, 16.69
# 2007-04-20, BUY EXECUTED, Price: 16.88, Cost: 168.80, Comm 0.00, Size 10.00
# 2007-04-20, SELL EXECUTED, Price: 16.88, Cost: 167.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.739997062683102
# - Price orig: 16.739997062683102
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.9
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-20, BUY CREATE, 16.90
# 2007-04-20, close long, 16.90
# 2007-04-23, BUY EXECUTED, Price: 16.87, Cost: 168.70, Comm 0.00, Size 10.00
# 2007-04-23, SELL EXECUTED, Price: 16.87, Cost: 168.05, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.80499853134155
# - Price orig: 16.80499853134155
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.85
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-23, BUY CREATE, 16.85
# 2007-04-23, close long, 16.85
# 2007-04-24, BUY EXECUTED, Price: 16.94, Cost: 169.40, Comm 0.00, Size 10.00
# 2007-04-24, SELL EXECUTED, Price: 16.94, Cost: 168.72, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.872499265670776
# - Price orig: 16.872499265670776
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.74
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-24, BUY CREATE, 16.74
# 2007-04-24, close long, 16.74
# 2007-04-25, BUY EXECUTED, Price: 16.80, Cost: 168.00, Comm 0.00, Size 10.00
# 2007-04-25, SELL EXECUTED, Price: 16.80, Cost: 168.36, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.836249632835386
# - Price orig: 16.836249632835386
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-25, BUY CREATE, 16.81
# 2007-04-25, close long, 16.81
# 2007-04-26, BUY EXECUTED, Price: 16.70, Cost: 167.00, Comm 0.00, Size 10.00
# 2007-04-26, SELL EXECUTED, Price: 16.70, Cost: 167.68, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.768124816417693
# - Price orig: 16.768124816417693
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-26, BUY CREATE, 16.86
# 2007-04-26, close long, 16.86
# 2007-04-27, BUY EXECUTED, Price: 16.86, Cost: 168.60, Comm 0.00, Size 10.00
# 2007-04-27, SELL EXECUTED, Price: 16.86, Cost: 168.14, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.814062408208848
# - Price orig: 16.814062408208848
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.99
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-04-27, BUY CREATE, 16.99
# 2007-04-27, close long, 16.99
# 2007-04-30, BUY EXECUTED, Price: 16.99, Cost: 169.90, Comm 0.00, Size 10.00
# 2007-04-30, SELL EXECUTED, Price: 16.99, Cost: 169.02, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.902031204104425
# - Price orig: 16.902031204104425
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.72
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 16.902031204104425
# - Price orig: 16.902031204104425
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.54
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 16.902031204104425
# - Price orig: 16.902031204104425
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-02, BUY CREATE, 16.78
# 2007-05-02, close long, 16.78
# 2007-05-03, BUY EXECUTED, Price: 16.82, Cost: 168.20, Comm 0.00, Size 10.00
# 2007-05-03, SELL EXECUTED, Price: 16.82, Cost: 168.61, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.861015602052213
# - Price orig: 16.861015602052213
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.92
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-03, BUY CREATE, 16.92
# 2007-05-03, close long, 16.92
# 2007-05-04, BUY EXECUTED, Price: 16.94, Cost: 169.40, Comm 0.00, Size 10.00
# 2007-05-04, SELL EXECUTED, Price: 16.94, Cost: 169.01, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.900507801026105
# - Price orig: 16.900507801026105
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.93
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-04, BUY CREATE, 16.93
# 2007-05-04, close long, 16.93
# 2007-05-07, BUY EXECUTED, Price: 16.92, Cost: 169.20, Comm 0.00, Size 10.00
# 2007-05-07, SELL EXECUTED, Price: 16.92, Cost: 169.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.910253900513055
# - Price orig: 16.910253900513055
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.94
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-07, BUY CREATE, 16.94
# 2007-05-07, close long, 16.94
# 2007-05-08, BUY EXECUTED, Price: 16.84, Cost: 168.40, Comm 0.00, Size 10.00
# 2007-05-08, SELL EXECUTED, Price: 16.84, Cost: 168.75, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.875126950256526
# - Price orig: 16.875126950256526
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-08, BUY CREATE, 16.86
# 2007-05-08, close long, 16.86
# 2007-05-09, BUY EXECUTED, Price: 16.82, Cost: 168.20, Comm 0.00, Size 10.00
# 2007-05-09, SELL EXECUTED, Price: 16.82, Cost: 168.48, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 16.84756347512826
# - Price orig: 16.84756347512826
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.75
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 16.84756347512826
# - Price orig: 16.84756347512826
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.45
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-10, BUY CREATE, 16.45
# 2007-05-11, BUY EXECUTED, Price: 16.54, Cost: 165.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 16.69378173756413
# - Price orig: 16.84756347512826
# - Closed: 0
# - Opened: 10
# - Adjbase: 16.88
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-11, close long, 16.88
# 2007-05-14, SELL EXECUTED, Price: 16.85, Cost: 333.88, Comm 0.00, Size -20.00
# 2007-05-14, OPERATION PROFIT, GROSS 9.50, NET 9.50
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 16.69378173756413
# - Closed: -20
# - Opened: 0
# - Adjbase: 16.88
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-14, close short, 16.85
# 2007-05-15, BUY EXECUTED, Price: 16.80, Cost: 168.00, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 16.8
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 16.76
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-15, close long, 16.76
# 2007-05-16, SELL EXECUTED, Price: 16.78, Cost: 168.00, Comm 0.00, Size -10.00
# 2007-05-16, OPERATION PROFIT, GROSS -0.20, NET -0.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 16.8
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.76
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-16, SELL CREATE, 16.89
# 2007-05-17, SELL EXECUTED, Price: 16.78, Cost: -167.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 16.78
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 16.94
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-17, SELL CREATE, 16.94
# 2007-05-18, SELL EXECUTED, Price: 16.96, Cost: -169.60, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 16.87
# - Price orig: 16.78
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.12
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-18, SELL CREATE, 17.12
# 2007-05-21, SELL EXECUTED, Price: 17.08, Cost: -170.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 16.94
# - Price orig: 16.87
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-21, SELL CREATE, 17.18
# 2007-05-22, SELL EXECUTED, Price: 17.25, Cost: -172.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -40
# - Price: 17.017500000000002
# - Price orig: 16.94
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-22, close short, 17.23
# 2007-05-23, BUY EXECUTED, Price: 17.24, Cost: -680.70, Comm 0.00, Size 40.00
# 2007-05-23, OPERATION PROFIT, GROSS -8.90, NET -8.90
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.017500000000002
# - Closed: 40
# - Opened: 0
# - Adjbase: 17.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-23, close short, 17.04
# 2007-05-24, BUY EXECUTED, Price: 17.02, Cost: 170.20, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.02
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 16.68
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-05-24, BUY CREATE, 16.68
# 2007-05-25, BUY EXECUTED, Price: 16.80, Cost: 168.00, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 16.91
# - Price orig: 17.02
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.11
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-25, BUY CREATE, 17.11
# 2007-05-25, close long, 17.11
# 2007-05-29, BUY EXECUTED, Price: 17.16, Cost: 171.60, Comm 0.00, Size 10.00
# 2007-05-29, SELL EXECUTED, Price: 17.16, Cost: 339.87, Comm 0.00, Size -20.00
# --- Position Begin
# - Size: 10
# - Price: 16.993333333333332
# - Price orig: 16.993333333333332
# - Closed: -20
# - Opened: 0
# - Adjbase: 17.18
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-29, BUY CREATE, 17.18
# 2007-05-29, close long, 17.18
# 2007-05-30, BUY EXECUTED, Price: 17.12, Cost: 171.20, Comm 0.00, Size 10.00
# 2007-05-30, SELL EXECUTED, Price: 17.12, Cost: 170.57, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.056666666666665
# - Price orig: 17.056666666666665
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-30, BUY CREATE, 17.27
# 2007-05-30, close long, 17.27
# 2007-05-31, BUY EXECUTED, Price: 17.25, Cost: 172.50, Comm 0.00, Size 10.00
# 2007-05-31, SELL EXECUTED, Price: 17.25, Cost: 171.53, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.153333333333332
# - Price orig: 17.153333333333332
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.24
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-05-31, BUY CREATE, 17.24
# 2007-05-31, close long, 17.24
# 2007-06-01, BUY EXECUTED, Price: 17.30, Cost: 173.00, Comm 0.00, Size 10.00
# 2007-06-01, SELL EXECUTED, Price: 17.30, Cost: 172.27, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.226666666666667
# - Price orig: 17.226666666666667
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.49
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-01, BUY CREATE, 17.49
# 2007-06-01, close long, 17.49
# 2007-06-04, BUY EXECUTED, Price: 17.39, Cost: 173.90, Comm 0.00, Size 10.00
# 2007-06-04, SELL EXECUTED, Price: 17.39, Cost: 173.08, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.30833333333333
# - Price orig: 17.30833333333333
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.5
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-04, BUY CREATE, 17.50
# 2007-06-04, close long, 17.50
# 2007-06-05, BUY EXECUTED, Price: 17.43, Cost: 174.30, Comm 0.00, Size 10.00
# 2007-06-05, SELL EXECUTED, Price: 17.43, Cost: 173.69, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.369166666666665
# - Price orig: 17.369166666666665
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.33
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-05, BUY CREATE, 17.33
# 2007-06-05, close long, 17.33
# 2007-06-06, BUY EXECUTED, Price: 17.23, Cost: 172.30, Comm 0.00, Size 10.00
# 2007-06-06, SELL EXECUTED, Price: 17.23, Cost: 173.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.299583333333334
# - Price orig: 17.299583333333334
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.21
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-06, BUY CREATE, 17.21
# 2007-06-06, close long, 17.21
# 2007-06-07, BUY EXECUTED, Price: 17.03, Cost: 170.30, Comm 0.00, Size 10.00
# 2007-06-07, SELL EXECUTED, Price: 17.03, Cost: 171.65, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.164791666666666
# - Price orig: 17.164791666666666
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 17.164791666666666
# - Price orig: 17.164791666666666
# - Closed: -10
# - Opened: 0
# - Adjbase: 16.95
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 17.164791666666666
# - Price orig: 17.164791666666666
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.09
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-11, close long, 17.09
# 2007-06-12, SELL EXECUTED, Price: 17.09, Cost: 171.65, Comm 0.00, Size -10.00
# 2007-06-12, OPERATION PROFIT, GROSS 4.30, NET 4.30
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.164791666666666
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.09
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-12, close short, 16.76
# 2007-06-13, BUY EXECUTED, Price: 16.78, Cost: 167.80, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 16.78
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.17
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-13, close long, 17.17
# 2007-06-14, SELL EXECUTED, Price: 17.39, Cost: 167.80, Comm 0.00, Size -10.00
# 2007-06-14, OPERATION PROFIT, GROSS 6.10, NET 6.10
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 16.78
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.17
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-14, SELL CREATE, 17.47
# 2007-06-15, SELL EXECUTED, Price: 17.71, Cost: -177.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 17.71
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.67
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-15, SELL CREATE, 17.67
# 2007-06-18, SELL EXECUTED, Price: 17.72, Cost: -177.20, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 17.715
# - Price orig: 17.71
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.6
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-18, SELL CREATE, 17.60
# 2007-06-19, SELL EXECUTED, Price: 17.60, Cost: -176.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 17.676666666666666
# - Price orig: 17.715
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.68
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-19, SELL CREATE, 17.68
# 2007-06-20, SELL EXECUTED, Price: 17.75, Cost: -177.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -40
# - Price: 17.695
# - Price orig: 17.676666666666666
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.37
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-20, close short, 17.37
# 2007-06-21, BUY EXECUTED, Price: 17.41, Cost: -707.80, Comm 0.00, Size 40.00
# 2007-06-21, OPERATION PROFIT, GROSS 11.40, NET 11.40
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.695
# - Closed: 40
# - Opened: 0
# - Adjbase: 17.37
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-06-21, close short, 17.51
# 2007-06-22, BUY EXECUTED, Price: 17.43, Cost: 174.30, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.43
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.25
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-22, close long, 17.25
# 2007-06-25, SELL EXECUTED, Price: 17.30, Cost: 174.30, Comm 0.00, Size -10.00
# 2007-06-25, OPERATION PROFIT, GROSS -1.30, NET -1.30
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.43
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.25
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-25, close short, 17.33
# 2007-06-26, BUY EXECUTED, Price: 17.45, Cost: 174.50, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.45
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.04
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-26, BUY CREATE, 17.04
# 2007-06-27, BUY EXECUTED, Price: 17.18, Cost: 171.80, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 17.315
# - Price orig: 17.45
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.51
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-27, close long, 17.51
# 2007-06-28, SELL EXECUTED, Price: 17.45, Cost: 346.30, Comm 0.00, Size -20.00
# 2007-06-28, OPERATION PROFIT, GROSS 2.70, NET 2.70
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.315
# - Closed: -20
# - Opened: 0
# - Adjbase: 17.51
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-28, SELL CREATE, 17.66
# 2007-06-29, SELL EXECUTED, Price: 17.75, Cost: -177.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 17.75
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.53
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-06-29, SELL CREATE, 17.53
# 2007-07-02, SELL EXECUTED, Price: 17.68, Cost: -176.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 17.715
# - Price orig: 17.75
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.72
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-02, close short, 17.72
# 2007-07-03, BUY EXECUTED, Price: 17.76, Cost: -354.30, Comm 0.00, Size 20.00
# 2007-07-03, OPERATION PROFIT, GROSS -0.90, NET -0.90
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.715
# - Closed: 20
# - Opened: 0
# - Adjbase: 17.72
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-03, close short, 17.85
# 2007-07-05, BUY EXECUTED, Price: 17.84, Cost: 178.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.84
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-05, BUY CREATE, 18.23
# 2007-07-05, close long, 18.23
# 2007-07-06, BUY EXECUTED, Price: 18.19, Cost: 181.90, Comm 0.00, Size 10.00
# 2007-07-06, SELL EXECUTED, Price: 18.19, Cost: 180.15, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.015
# - Price orig: 18.015
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-06, BUY CREATE, 18.15
# 2007-07-06, close long, 18.15
# 2007-07-09, BUY EXECUTED, Price: 18.00, Cost: 180.00, Comm 0.00, Size 10.00
# 2007-07-09, SELL EXECUTED, Price: 18.00, Cost: 180.07, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.0075
# - Price orig: 18.0075
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.93
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-09, BUY CREATE, 17.93
# 2007-07-09, close long, 17.93
# 2007-07-10, BUY EXECUTED, Price: 17.80, Cost: 178.00, Comm 0.00, Size 10.00
# 2007-07-10, SELL EXECUTED, Price: 17.80, Cost: 179.04, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.90375
# - Price orig: 17.90375
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.54
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 17.90375
# - Price orig: 17.90375
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.77
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-11, BUY CREATE, 17.77
# 2007-07-11, close long, 17.77
# 2007-07-12, BUY EXECUTED, Price: 17.83, Cost: 178.30, Comm 0.00, Size 10.00
# 2007-07-12, SELL EXECUTED, Price: 17.83, Cost: 178.67, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.866875
# - Price orig: 17.866875
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-12, BUY CREATE, 18.23
# 2007-07-12, close long, 18.23
# 2007-07-13, BUY EXECUTED, Price: 18.23, Cost: 182.30, Comm 0.00, Size 10.00
# 2007-07-13, SELL EXECUTED, Price: 18.23, Cost: 180.48, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.0484375
# - Price orig: 18.0484375
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-13, BUY CREATE, 18.15
# 2007-07-13, close long, 18.15
# 2007-07-16, BUY EXECUTED, Price: 18.05, Cost: 180.50, Comm 0.00, Size 10.00
# 2007-07-16, SELL EXECUTED, Price: 18.05, Cost: 180.49, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.04921875
# - Price orig: 18.04921875
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.97
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-16, BUY CREATE, 17.97
# 2007-07-16, close long, 17.97
# 2007-07-17, BUY EXECUTED, Price: 18.01, Cost: 180.10, Comm 0.00, Size 10.00
# 2007-07-17, SELL EXECUTED, Price: 18.01, Cost: 180.30, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.029609375
# - Price orig: 18.029609375
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.13
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-17, BUY CREATE, 18.13
# 2007-07-17, close long, 18.13
# 2007-07-18, BUY EXECUTED, Price: 17.97, Cost: 179.70, Comm 0.00, Size 10.00
# 2007-07-18, SELL EXECUTED, Price: 17.97, Cost: 180.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.9998046875
# - Price orig: 17.9998046875
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-18, BUY CREATE, 18.15
# 2007-07-18, close long, 18.15
# 2007-07-19, BUY EXECUTED, Price: 18.29, Cost: 182.90, Comm 0.00, Size 10.00
# 2007-07-19, SELL EXECUTED, Price: 18.29, Cost: 181.45, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.144902343749997
# - Price orig: 18.144902343749997
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.32
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-19, BUY CREATE, 18.32
# 2007-07-19, close long, 18.32
# 2007-07-20, BUY EXECUTED, Price: 18.58, Cost: 185.80, Comm 0.00, Size 10.00
# 2007-07-20, SELL EXECUTED, Price: 18.58, Cost: 183.62, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.362451171875
# - Price orig: 18.362451171875
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.33
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-20, BUY CREATE, 18.33
# 2007-07-20, close long, 18.33
# 2007-07-23, BUY EXECUTED, Price: 18.51, Cost: 185.10, Comm 0.00, Size 10.00
# 2007-07-23, SELL EXECUTED, Price: 18.51, Cost: 184.36, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.4362255859375
# - Price orig: 18.4362255859375
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.48
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-23, BUY CREATE, 18.48
# 2007-07-23, close long, 18.48
# 2007-07-24, BUY EXECUTED, Price: 18.48, Cost: 184.80, Comm 0.00, Size 10.00
# 2007-07-24, SELL EXECUTED, Price: 18.48, Cost: 184.58, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.458112792968752
# - Price orig: 18.458112792968752
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.36
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-24, BUY CREATE, 18.36
# 2007-07-24, close long, 18.36
# 2007-07-25, BUY EXECUTED, Price: 18.41, Cost: 184.10, Comm 0.00, Size 10.00
# 2007-07-25, SELL EXECUTED, Price: 18.41, Cost: 184.34, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.434056396484372
# - Price orig: 18.434056396484372
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.31
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-07-25, BUY CREATE, 18.31
# 2007-07-25, close long, 18.31
# 2007-07-26, BUY EXECUTED, Price: 17.98, Cost: 179.80, Comm 0.00, Size 10.00
# 2007-07-26, SELL EXECUTED, Price: 17.98, Cost: 182.07, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.207028198242188
# - Price orig: 18.207028198242188
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.8
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 18.207028198242188
# - Price orig: 18.207028198242188
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.45
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 18.207028198242188
# - Price orig: 18.207028198242188
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.42
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-07-30, BUY CREATE, 17.42
# 2007-07-31, BUY EXECUTED, Price: 17.60, Cost: 176.00, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 17.903514099121093
# - Price orig: 18.207028198242188
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-07-31, BUY CREATE, 17.01
# 2007-08-01, BUY EXECUTED, Price: 16.84, Cost: 168.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 30
# - Price: 17.54900939941406
# - Price orig: 17.903514099121093
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.6
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-01, BUY CREATE, 17.60
# 2007-08-02, BUY EXECUTED, Price: 17.58, Cost: 175.80, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 40
# - Price: 17.556757049560545
# - Price orig: 17.54900939941406
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-02, close long, 17.87
# 2007-08-03, SELL EXECUTED, Price: 17.87, Cost: 702.27, Comm 0.00, Size -40.00
# 2007-08-03, OPERATION PROFIT, GROSS 16.20, NET 16.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.556757049560545
# - Closed: -40
# - Opened: 0
# - Adjbase: 17.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-03, close short, 17.49
# 2007-08-06, BUY EXECUTED, Price: 17.63, Cost: 176.30, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.63
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.86
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-06, close long, 17.86
# 2007-08-07, SELL EXECUTED, Price: 17.67, Cost: 176.30, Comm 0.00, Size -10.00
# 2007-08-07, OPERATION PROFIT, GROSS 0.40, NET 0.40
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.63
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.86
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-07, close short, 17.51
# 2007-08-08, BUY EXECUTED, Price: 17.75, Cost: 177.50, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.75
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.97
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-08-08, BUY CREATE, 17.97
# 2007-08-08, close long, 17.97
# 2007-08-09, BUY EXECUTED, Price: 17.74, Cost: 177.40, Comm 0.00, Size 10.00
# 2007-08-09, SELL EXECUTED, Price: 17.74, Cost: 177.45, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 17.744999999999997
# - Price orig: 17.744999999999997
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-09, close long, 17.87
# 2007-08-10, SELL EXECUTED, Price: 17.57, Cost: 177.45, Comm 0.00, Size -10.00
# 2007-08-10, OPERATION PROFIT, GROSS -1.80, NET -1.80
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.744999999999997
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-10, close short, 17.78
# 2007-08-13, BUY EXECUTED, Price: 17.73, Cost: 177.30, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.73
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.54
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-13, BUY CREATE, 17.54
# 2007-08-14, BUY EXECUTED, Price: 17.61, Cost: 176.10, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.21
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.06
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.02
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.21
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.0
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.14
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 17.669999999999998
# - Price orig: 17.73
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-22, BUY CREATE, 17.18
# 2007-08-23, BUY EXECUTED, Price: 17.24, Cost: 172.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 30
# - Price: 17.526666666666664
# - Price orig: 17.669999999999998
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.23
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-23, BUY CREATE, 17.23
# 2007-08-24, BUY EXECUTED, Price: 17.17, Cost: 171.70, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 40
# - Price: 17.4375
# - Price orig: 17.526666666666664
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-24, close long, 17.74
# 2007-08-27, SELL EXECUTED, Price: 17.75, Cost: 697.50, Comm 0.00, Size -40.00
# 2007-08-27, OPERATION PROFIT, GROSS 12.50, NET 12.50
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.4375
# - Closed: -40
# - Opened: 0
# - Adjbase: 17.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-27, SELL CREATE, 17.67
# 2007-08-28, SELL EXECUTED, Price: 17.61, Cost: -176.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 17.61
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.22
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-28, close short, 17.22
# 2007-08-29, BUY EXECUTED, Price: 17.27, Cost: -176.10, Comm 0.00, Size 10.00
# 2007-08-29, OPERATION PROFIT, GROSS 3.40, NET 3.40
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.61
# - Closed: 10
# - Opened: 0
# - Adjbase: 17.22
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-29, SELL CREATE, 17.91
# 2007-08-30, SELL EXECUTED, Price: 17.75, Cost: -177.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 17.75
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 17.98
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-30, SELL CREATE, 17.98
# 2007-08-31, SELL EXECUTED, Price: 18.17, Cost: -181.70, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 17.96
# - Price orig: 17.75
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.04
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-08-31, SELL CREATE, 18.04
# 2007-09-04, SELL EXECUTED, Price: 18.00, Cost: -180.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 17.973333333333336
# - Price orig: 17.96
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.43
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-09-04, SELL CREATE, 18.43
# 2007-09-05, SELL EXECUTED, Price: 18.23, Cost: -182.30, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -40
# - Price: 18.0375
# - Price orig: 17.973333333333336
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.44
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-09-05, SELL CREATE, 18.44
# 2007-09-06, SELL EXECUTED, Price: 18.43, Cost: -184.30, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -50
# - Price: 18.116
# - Price orig: 18.0375
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-06, close short, 18.27
# 2007-09-07, BUY EXECUTED, Price: 17.99, Cost: -905.80, Comm 0.00, Size 50.00
# 2007-09-07, OPERATION PROFIT, GROSS 6.30, NET 6.30
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 18.116
# - Closed: 50
# - Opened: 0
# - Adjbase: 18.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-07, close short, 17.93
# 2007-09-10, BUY EXECUTED, Price: 18.09, Cost: 180.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 18.09
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.94
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-10, BUY CREATE, 17.94
# 2007-09-10, close long, 17.94
# 2007-09-11, BUY EXECUTED, Price: 17.99, Cost: 179.90, Comm 0.00, Size 10.00
# 2007-09-11, SELL EXECUTED, Price: 17.99, Cost: 180.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.04
# - Price orig: 18.04
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.2
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-11, BUY CREATE, 18.20
# 2007-09-11, close long, 18.20
# 2007-09-12, BUY EXECUTED, Price: 18.10, Cost: 181.00, Comm 0.00, Size 10.00
# 2007-09-12, SELL EXECUTED, Price: 18.10, Cost: 180.70, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.07
# - Price orig: 18.07
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-12, BUY CREATE, 18.27
# 2007-09-12, close long, 18.27
# 2007-09-13, BUY EXECUTED, Price: 18.41, Cost: 184.10, Comm 0.00, Size 10.00
# 2007-09-13, SELL EXECUTED, Price: 18.41, Cost: 182.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.24
# - Price orig: 18.24
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.19
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-09-13, BUY CREATE, 18.19
# 2007-09-13, close long, 18.19
# 2007-09-14, BUY EXECUTED, Price: 18.14, Cost: 181.40, Comm 0.00, Size 10.00
# 2007-09-14, SELL EXECUTED, Price: 18.14, Cost: 181.90, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.189999999999998
# - Price orig: 18.189999999999998
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.85
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 18.189999999999998
# - Price orig: 18.189999999999998
# - Closed: -10
# - Opened: 0
# - Adjbase: 17.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 18.189999999999998
# - Price orig: 18.189999999999998
# - Closed: -10
# ...
# 2007-10-11, BUY EXECUTED, Price: 20.41, Cost: 204.10, Comm 0.00, Size 10.00
# 2007-10-11, SELL EXECUTED, Price: 20.41, Cost: 201.71, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.170960540771482
# - Price orig: 20.170960540771482
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-10-11, BUY CREATE, 19.98
# 2007-10-11, close long, 19.98
# 2007-10-12, BUY EXECUTED, Price: 19.92, Cost: 199.20, Comm 0.00, Size 10.00
# 2007-10-12, SELL EXECUTED, Price: 19.92, Cost: 200.45, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.04548027038574
# - Price orig: 20.04548027038574
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.96
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-10-12, BUY CREATE, 19.96
# 2007-10-12, close long, 19.96
# 2007-10-15, BUY EXECUTED, Price: 20.06, Cost: 200.60, Comm 0.00, Size 10.00
# 2007-10-15, SELL EXECUTED, Price: 20.06, Cost: 200.53, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.05274013519287
# - Price orig: 20.05274013519287
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.63
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 20.05274013519287
# - Price orig: 20.05274013519287
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.35
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 20.05274013519287
# - Price orig: 20.05274013519287
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.12
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-17, BUY CREATE, 19.12
# 2007-10-18, BUY EXECUTED, Price: 19.12, Cost: 191.20, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 19.586370067596437
# - Price orig: 20.05274013519287
# - Closed: 0
# - Opened: 10
# - Adjbase: 19.06
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-18, BUY CREATE, 19.06
# 2007-10-19, BUY EXECUTED, Price: 19.06, Cost: 190.60, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 30
# - Price: 19.410913378397627
# - Price orig: 19.586370067596437
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.46
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-19, BUY CREATE, 18.46
# 2007-10-22, BUY EXECUTED, Price: 18.32, Cost: 183.20, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 40
# - Price: 19.13818503379822
# - Price orig: 19.410913378397627
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.86
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-22, BUY CREATE, 18.86
# 2007-10-23, BUY EXECUTED, Price: 19.04, Cost: 190.40, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 50
# - Price: 19.118548027038575
# - Price orig: 19.13818503379822
# - Closed: 0
# - Opened: 10
# - Adjbase: 19.08
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-23, BUY CREATE, 19.08
# 2007-10-24, Order Canceled/Margin/Rejected
# --- Position Begin
# - Size: 50
# - Price: 19.118548027038575
# - Price orig: 19.13818503379822
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.84
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-10-24, BUY CREATE, 18.84
# 2007-10-25, Order Canceled/Margin/Rejected
# --- Position Begin
# - Size: 50
# - Price: 19.118548027038575
# - Price orig: 19.13818503379822
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.68
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 50
# - Price: 19.118548027038575
# - Price orig: 19.13818503379822
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.99
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 50
# - Price: 19.118548027038575
# - Price orig: 19.13818503379822
# - Closed: 0
# - Opened: 10
# - Adjbase: 19.36
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-10-29, BUY CREATE, 19.36
# 2007-10-29, close long, 19.36
# 2007-10-30, Order Canceled/Margin/Rejected
# 2007-10-30, SELL EXECUTED, Price: 19.26, Cost: 955.93, Comm 0.00, Size -50.00
# 2007-10-30, OPERATION PROFIT, GROSS 26.70, NET 26.70
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 19.118548027038575
# - Closed: -50
# - Opened: 0
# - Adjbase: 19.36
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-10-30, SELL CREATE, 19.24
# 2007-10-31, SELL EXECUTED, Price: 19.25, Cost: -192.50, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 19.25
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 19.72
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-10-31, close short, 19.72
# 2007-11-01, BUY EXECUTED, Price: 19.57, Cost: -192.50, Comm 0.00, Size 10.00
# 2007-11-01, OPERATION PROFIT, GROSS -3.20, NET -3.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 19.25
# - Closed: 10
# - Opened: 0
# - Adjbase: 19.72
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-11-01, close short, 19.36
# 2007-11-02, BUY EXECUTED, Price: 19.40, Cost: 194.00, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 19.4
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 19.6
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-02, close long, 19.60
# 2007-11-05, SELL EXECUTED, Price: 19.42, Cost: 194.00, Comm 0.00, Size -10.00
# 2007-11-05, OPERATION PROFIT, GROSS 0.20, NET 0.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 19.4
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.6
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-05, SELL CREATE, 19.63
# 2007-11-06, SELL EXECUTED, Price: 20.04, Cost: -200.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 20.04
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 20.31
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-06, SELL CREATE, 20.31
# 2007-11-07, SELL EXECUTED, Price: 20.01, Cost: -200.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 20.025
# - Price orig: 20.04
# - Closed: 0
# - Opened: -10
# - Adjbase: 19.66
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-07, SELL CREATE, 19.66
# 2007-11-08, SELL EXECUTED, Price: 19.48, Cost: -194.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 19.84333333333333
# - Price orig: 20.025
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.1
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-08, close short, 18.10
# 2007-11-09, BUY EXECUTED, Price: 17.73, Cost: -595.30, Comm 0.00, Size 30.00
# 2007-11-09, OPERATION PROFIT, GROSS 63.40, NET 63.40
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 19.84333333333333
# - Closed: 30
# - Opened: 0
# - Adjbase: 18.1
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-09, close short, 17.22
# 2007-11-12, BUY EXECUTED, Price: 17.12, Cost: 171.20, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.12
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.29
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-12, BUY CREATE, 17.29
# 2007-11-13, BUY EXECUTED, Price: 17.61, Cost: 176.10, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 17.365000000000002
# - Price orig: 17.12
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.25
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-13, BUY CREATE, 18.25
# 2007-11-14, BUY EXECUTED, Price: 18.53, Cost: 185.30, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 30
# - Price: 17.753333333333337
# - Price orig: 17.365000000000002
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.95
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-14, BUY CREATE, 17.95
# 2007-11-15, BUY EXECUTED, Price: 17.72, Cost: 177.20, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 40
# - Price: 17.745000000000005
# - Price orig: 17.753333333333337
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.16
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-15, BUY CREATE, 18.16
# 2007-11-16, BUY EXECUTED, Price: 18.16, Cost: 181.60, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 50
# - Price: 17.828000000000003
# - Price orig: 17.745000000000005
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.5
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-16, close long, 18.50
# 2007-11-19, SELL EXECUTED, Price: 18.37, Cost: 891.40, Comm 0.00, Size -50.00
# 2007-11-19, OPERATION PROFIT, GROSS 27.10, NET 27.10
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.828000000000003
# - Closed: -50
# - Opened: 0
# - Adjbase: 18.5
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-19, close short, 18.26
# 2007-11-20, BUY EXECUTED, Price: 18.18, Cost: 181.80, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 18.18
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.4
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-20, close long, 18.40
# 2007-11-21, SELL EXECUTED, Price: 18.01, Cost: 181.80, Comm 0.00, Size -10.00
# 2007-11-21, OPERATION PROFIT, GROSS -1.70, NET -1.70
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 18.18
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.4
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-21, close short, 17.98
# 2007-11-23, BUY EXECUTED, Price: 18.00, Cost: 180.00, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 18.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.07
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-23, BUY CREATE, 18.07
# 2007-11-26, BUY EXECUTED, Price: 18.13, Cost: 181.30, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 20
# - Price: 18.064999999999998
# - Price orig: 18.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.52
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 18.064999999999998
# - Price orig: 18.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 17.69
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 20
# - Price: 18.064999999999998
# - Price orig: 18.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.24
# --- Position End
# decreasing
# 有趋势,使用均线法则
# 2007-11-28, BUY CREATE, 18.24
# 2007-11-28, close long, 18.24
# 2007-11-29, BUY EXECUTED, Price: 18.22, Cost: 182.20, Comm 0.00, Size 10.00
# 2007-11-29, SELL EXECUTED, Price: 18.22, Cost: 362.33, Comm 0.00, Size -20.00
# --- Position Begin
# - Size: 10
# - Price: 18.116666666666667
# - Price orig: 18.116666666666667
# - Closed: -20
# - Opened: 0
# - Adjbase: 18.22
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-29, close long, 18.22
# 2007-11-30, SELL EXECUTED, Price: 18.48, Cost: 181.17, Comm 0.00, Size -10.00
# 2007-11-30, OPERATION PROFIT, GROSS 5.70, NET 5.70
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 18.116666666666667
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.22
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-11-30, close short, 17.95
# 2007-12-03, BUY EXECUTED, Price: 17.99, Cost: 179.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.99
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.0
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-03, close long, 18.00
# 2007-12-04, SELL EXECUTED, Price: 17.57, Cost: 179.90, Comm 0.00, Size -10.00
# 2007-12-04, OPERATION PROFIT, GROSS -4.20, NET -4.20
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.99
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.0
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-04, close short, 17.82
# 2007-12-05, BUY EXECUTED, Price: 17.99, Cost: 179.90, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 17.99
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-05, close long, 18.87
# 2007-12-06, SELL EXECUTED, Price: 18.77, Cost: 179.90, Comm 0.00, Size -10.00
# 2007-12-06, OPERATION PROFIT, GROSS 7.80, NET 7.80
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 17.99
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.87
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-06, SELL CREATE, 19.05
# 2007-12-07, SELL EXECUTED, Price: 19.12, Cost: -191.20, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -10
# - Price: 19.12
# - Price orig: 0.0
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.8
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-07, SELL CREATE, 18.80
# 2007-12-10, SELL EXECUTED, Price: 18.94, Cost: -189.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -20
# - Price: 19.03
# - Price orig: 19.12
# - Closed: 0
# - Opened: -10
# - Adjbase: 19.25
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-10, SELL CREATE, 19.25
# 2007-12-11, SELL EXECUTED, Price: 19.30, Cost: -193.00, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -30
# - Price: 19.12
# - Price orig: 19.03
# - Closed: 0
# - Opened: -10
# - Adjbase: 18.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-11, SELL CREATE, 18.74
# 2007-12-12, SELL EXECUTED, Price: 19.04, Cost: -190.40, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -40
# - Price: 19.1
# - Price orig: 19.12
# - Closed: 0
# - Opened: -10
# - Adjbase: 19.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# 2007-12-12, SELL CREATE, 19.01
# 2007-12-13, SELL EXECUTED, Price: 18.98, Cost: -189.80, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: -50
# - Price: 19.076
# - Price orig: 19.1
# - Closed: 0
# - Opened: -10
# - Adjbase: 19.22
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-13, close short, 19.22
# 2007-12-14, BUY EXECUTED, Price: 19.00, Cost: -953.80, Comm 0.00, Size 50.00
# 2007-12-14, OPERATION PROFIT, GROSS 3.80, NET 3.80
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 19.076
# - Closed: 50
# - Opened: 0
# - Adjbase: 19.22
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-14, close short, 18.86
# 2007-12-17, BUY EXECUTED, Price: 18.81, Cost: 188.10, Comm 0.00, Size 10.00
# --- Position Begin
# - Size: 10
# - Price: 18.81
# - Price orig: 0.0
# - Closed: 0
# - Opened: 10
# - Adjbase: 18.63
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-17, BUY CREATE, 18.63
# 2007-12-17, close long, 18.63
# 2007-12-18, BUY EXECUTED, Price: 18.76, Cost: 187.60, Comm 0.00, Size 10.00
# 2007-12-18, SELL EXECUTED, Price: 18.76, Cost: 187.85, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.785000000000004
# - Price orig: 18.785000000000004
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.9
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-18, BUY CREATE, 18.90
# 2007-12-18, close long, 18.90
# 2007-12-19, BUY EXECUTED, Price: 18.97, Cost: 189.70, Comm 0.00, Size 10.00
# 2007-12-19, SELL EXECUTED, Price: 18.97, Cost: 188.78, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 18.8775
# - Price orig: 18.8775
# - Closed: -10
# - Opened: 0
# - Adjbase: 18.47
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 10
# - Price: 18.8775
# - Price orig: 18.8775
# - Closed: -10
# - Opened: 0
# - Adjbase: 19.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-20, BUY CREATE, 19.66
# 2007-12-20, close long, 19.66
# 2007-12-21, BUY EXECUTED, Price: 19.84, Cost: 198.40, Comm 0.00, Size 10.00
# 2007-12-21, SELL EXECUTED, Price: 19.84, Cost: 193.59, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 19.35875
# - Price orig: 19.35875
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.2
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-21, BUY CREATE, 20.20
# 2007-12-21, close long, 20.20
# 2007-12-24, BUY EXECUTED, Price: 20.14, Cost: 201.40, Comm 0.00, Size 10.00
# 2007-12-24, SELL EXECUTED, Price: 20.14, Cost: 197.49, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 19.749375
# - Price orig: 19.749375
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.24
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-24, BUY CREATE, 20.24
# 2007-12-24, close long, 20.24
# 2007-12-26, BUY EXECUTED, Price: 20.07, Cost: 200.70, Comm 0.00, Size 10.00
# 2007-12-26, SELL EXECUTED, Price: 20.07, Cost: 199.10, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 19.9096875
# - Price orig: 19.9096875
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.46
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-26, BUY CREATE, 20.46
# 2007-12-26, close long, 20.46
# 2007-12-27, BUY EXECUTED, Price: 20.50, Cost: 205.00, Comm 0.00, Size 10.00
# 2007-12-27, SELL EXECUTED, Price: 20.50, Cost: 202.05, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.204843750000002
# - Price orig: 20.204843750000002
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.49
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-27, BUY CREATE, 20.49
# 2007-12-27, close long, 20.49
# 2007-12-28, BUY EXECUTED, Price: 20.56, Cost: 205.60, Comm 0.00, Size 10.00
# 2007-12-28, SELL EXECUTED, Price: 20.56, Cost: 203.82, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.382421875
# - Price orig: 20.382421875
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.43
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-28, BUY CREATE, 20.43
# 2007-12-28, close long, 20.43
# 2007-12-31, BUY EXECUTED, Price: 20.18, Cost: 201.80, Comm 0.00, Size 10.00
# 2007-12-31, SELL EXECUTED, Price: 20.18, Cost: 202.81, Comm 0.00, Size -10.00
# --- Position Begin
# - Size: 10
# - Price: 20.2812109375
# - Price orig: 20.2812109375
# - Closed: -10
# - Opened: 0
# - Adjbase: 20.08
# --- Position End
# increasing
# 有趋势,使用均线法则
# 2007-12-31, BUY CREATE, 20.08
# 2007-12-31, close long, 20.08
# Final Portfolio Value: 1178.20
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# 直接用布林线法则

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import numpy as np
import pymannkendall as mk

# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),('trend_test_period', 20), ("period", 20), ("devfactor", 0.5), ("debug", False)
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.data_trend_test = self.datas[0].get(size=10)  # ago defaults to 0
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        #设置变点检验的区间
        #初始化布林线
        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)
        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])
        #进行趋势检验
        self.trend_test_data = self.data.get(size=self.params.trend_test_period)
        trend, h, p, z, Tau, s, var_s, slope, intercept = mk.original_test(self.trend_test_data)
        print(self.trend_test_data )
        print(trend)
        #直接用布林线法则
        if not self.position:
            if self.data.close < self.boll.lines.bot:
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.order = self.buy()
        else:
            if self.data.close > self.boll.lines.top:
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[1]))
    datapath = os.path.join(modpath, 'D:\desktop\orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2007, 1, 1),
        # Do not pass values before this date
        todate=datetime.datetime(2008, 1, 1),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.plot(style='candlestick')
# Out:
# Starting Portfolio Value: 1000.00
# 2007-01-31, Close, 15.26
# array('d', [15.57, 15.73, 15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26])
# decreasing
# 2007-01-31, BUY CREATE, 15.26
# 2007-02-01, BUY EXECUTED, Price: 15.32, Cost: 153.20, Comm 0.00
# 2007-02-01, Close, 15.17
# array('d', [15.73, 15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17])
# decreasing
# 2007-02-02, Close, 15.49
# array('d', [15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49])
# decreasing
# 2007-02-05, Close, 15.26
# array('d', [15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26])
# decreasing
# 2007-02-06, Close, 15.14
# array('d', [15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14])
# decreasing
# 2007-02-07, Close, 15.04
# array('d', [15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04])
# decreasing
# 2007-02-08, Close, 14.86
# array('d', [15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86])
# decreasing
# 2007-02-09, Close, 14.85
# array('d', [15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85])
# decreasing
# 2007-02-12, Close, 14.81
# array('d', [15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81])
# decreasing
# 2007-02-13, Close, 14.78
# array('d', [15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78])
# decreasing
# 2007-02-14, Close, 14.92
# array('d', [15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92])
# decreasing
# 2007-02-15, Close, 15.04
# array('d', [15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04])
# decreasing
# 2007-02-16, Close, 14.85
# array('d', [15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85])
# decreasing
# 2007-02-20, Close, 15.10
# array('d', [15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1])
# decreasing
# 2007-02-21, Close, 15.30
# array('d', [15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3])
# decreasing
# 2007-02-21, SELL CREATE, 15.30
# 2007-02-22, SELL EXECUTED, Price: 15.35, Cost: 153.20, Comm 0.00
# 2007-02-22, OPERATION PROFIT, GROSS 0.30, NET 0.30
# 2007-02-22, Close, 15.36
# array('d', [15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36])
# no trend
# 2007-02-23, Close, 14.96
# array('d', [15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96])
# no trend
# 2007-02-23, BUY CREATE, 14.96
# 2007-02-26, BUY EXECUTED, Price: 15.04, Cost: 150.40, Comm 0.00
# 2007-02-26, Close, 14.96
# array('d', [15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96])
# no trend
# 2007-02-27, Close, 14.49
# array('d', [15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49])
# no trend
# 2007-02-28, Close, 14.61
# array('d', [15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61])
# decreasing
# 2007-03-01, Close, 14.92
# array('d', [15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92])
# no trend
# 2007-03-02, Close, 14.86
# array('d', [15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86])
# no trend
# 2007-03-05, Close, 14.56
# array('d', [15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56])
# no trend
# 2007-03-06, Close, 15.01
# array('d', [15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01])
# no trend
# 2007-03-07, Close, 14.67
# array('d', [15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67])
# no trend
# 2007-03-08, Close, 14.85
# array('d', [14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85])
# no trend
# 2007-03-09, Close, 14.79
# array('d', [14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79])
# no trend
# 2007-03-12, Close, 15.18
# array('d', [14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18])
# no trend
# 2007-03-12, SELL CREATE, 15.18
# 2007-03-13, SELL EXECUTED, Price: 15.06, Cost: 150.40, Comm 0.00
# 2007-03-13, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2007-03-13, Close, 14.81
# array('d', [14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81])
# no trend
# 2007-03-14, Close, 15.01
# array('d', [14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01])
# no trend
# 2007-03-15, Close, 14.87
# array('d', [15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87])
# no trend
# 2007-03-16, Close, 14.85
# array('d', [14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85])
# no trend
# 2007-03-19, Close, 15.28
# array('d', [15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28])
# no trend
# 2007-03-20, Close, 15.61
# array('d', [15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61])
# no trend
# 2007-03-21, Close, 16.16
# array('d', [15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16])
# no trend
# 2007-03-22, Close, 16.45
# array('d', [14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45])
# increasing
# 2007-03-23, Close, 16.22
# array('d', [14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22])
# increasing
# 2007-03-26, Close, 16.36
# array('d', [14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36])
# increasing
# 2007-03-27, Close, 16.45
# array('d', [14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45])
# increasing
# 2007-03-28, Close, 16.16
# array('d', [14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16])
# increasing
# 2007-03-29, Close, 16.15
# array('d', [14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15])
# increasing
# 2007-03-30, Close, 16.13
# array('d', [14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13])
# increasing
# 2007-04-02, Close, 16.14
# array('d', [15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14])
# increasing
# 2007-04-03, Close, 16.33
# array('d', [14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33])
# increasing
# 2007-04-04, Close, 16.51
# array('d', [14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51])
# increasing
# 2007-04-05, Close, 16.61
# array('d', [14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61])
# increasing
# 2007-04-09, Close, 16.52
# array('d', [15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52])
# increasing
# 2007-04-10, Close, 16.77
# array('d', [14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77])
# increasing
# 2007-04-11, Close, 16.54
# array('d', [15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54])
# increasing
# 2007-04-12, Close, 16.63
# array('d', [14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63])
# increasing
# 2007-04-13, Close, 16.57
# array('d', [14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57])
# increasing
# 2007-04-16, Close, 16.81
# array('d', [15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81])
# increasing
# 2007-04-17, Close, 16.80
# array('d', [15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8])
# increasing
# 2007-04-18, Close, 16.66
# array('d', [16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66])
# increasing
# 2007-04-19, Close, 16.69
# array('d', [16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69])
# increasing
# 2007-04-20, Close, 16.90
# array('d', [16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9])
# increasing
# 2007-04-23, Close, 16.85
# array('d', [16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85])
# increasing
# 2007-04-24, Close, 16.74
# array('d', [16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74])
# increasing
# 2007-04-25, Close, 16.81
# array('d', [16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81])
# increasing
# 2007-04-26, Close, 16.86
# array('d', [16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86])
# increasing
# 2007-04-27, Close, 16.99
# array('d', [16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99])
# increasing
# 2007-04-30, Close, 16.72
# array('d', [16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72])
# increasing
# 2007-05-01, Close, 16.54
# array('d', [16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54])
# increasing
# 2007-05-01, BUY CREATE, 16.54
# 2007-05-02, BUY EXECUTED, Price: 16.62, Cost: 166.20, Comm 0.00
# 2007-05-02, Close, 16.78
# array('d', [16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78])
# increasing
# 2007-05-03, Close, 16.92
# array('d', [16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92])
# increasing
# 2007-05-03, SELL CREATE, 16.92
# 2007-05-04, SELL EXECUTED, Price: 16.94, Cost: 166.20, Comm 0.00
# 2007-05-04, OPERATION PROFIT, GROSS 3.20, NET 3.20
# 2007-05-04, Close, 16.93
# array('d', [16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93])
# increasing
# 2007-05-07, Close, 16.94
# array('d', [16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94])
# increasing
# 2007-05-08, Close, 16.86
# array('d', [16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86])
# increasing
# 2007-05-09, Close, 16.75
# array('d', [16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75])
# increasing
# 2007-05-10, Close, 16.45
# array('d', [16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45])
# no trend
# 2007-05-10, BUY CREATE, 16.45
# 2007-05-11, BUY EXECUTED, Price: 16.54, Cost: 165.40, Comm 0.00
# 2007-05-11, Close, 16.88
# array('d', [16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88])
# no trend
# 2007-05-11, SELL CREATE, 16.88
# 2007-05-14, SELL EXECUTED, Price: 16.85, Cost: 165.40, Comm 0.00
# 2007-05-14, OPERATION PROFIT, GROSS 3.10, NET 3.10
# 2007-05-14, Close, 16.85
# array('d', [16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85])
# no trend
# 2007-05-15, Close, 16.76
# array('d', [16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76])
# no trend
# 2007-05-16, Close, 16.89
# array('d', [16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89])
# no trend
# 2007-05-17, Close, 16.94
# array('d', [16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94])
# no trend
# 2007-05-18, Close, 17.12
# array('d', [16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12])
# no trend
# 2007-05-21, Close, 17.18
# array('d', [16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18])
# no trend
# 2007-05-22, Close, 17.23
# array('d', [16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23])
# increasing
# 2007-05-23, Close, 17.04
# array('d', [16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04])
# increasing
# 2007-05-24, Close, 16.68
# array('d', [16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68])
# no trend
# 2007-05-24, BUY CREATE, 16.68
# 2007-05-25, BUY EXECUTED, Price: 16.80, Cost: 168.00, Comm 0.00
# 2007-05-25, Close, 17.11
# array('d', [16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11])
# increasing
# 2007-05-25, SELL CREATE, 17.11
# 2007-05-29, SELL EXECUTED, Price: 17.16, Cost: 168.00, Comm 0.00
# 2007-05-29, OPERATION PROFIT, GROSS 3.60, NET 3.60
# 2007-05-29, Close, 17.18
# array('d', [16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18])
# increasing
# 2007-05-30, Close, 17.27
# array('d', [16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27])
# increasing
# 2007-05-31, Close, 17.24
# array('d', [16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24])
# increasing
# 2007-06-01, Close, 17.49
# array('d', [16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49])
# increasing
# 2007-06-04, Close, 17.50
# array('d', [16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5])
# increasing
# 2007-06-05, Close, 17.33
# array('d', [16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33])
# increasing
# 2007-06-06, Close, 17.21
# array('d', [16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21])
# increasing
# 2007-06-07, Close, 16.66
# array('d', [16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66])
# increasing
# 2007-06-07, BUY CREATE, 16.66
# 2007-06-08, BUY EXECUTED, Price: 16.66, Cost: 166.60, Comm 0.00
# 2007-06-08, Close, 16.95
# array('d', [16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95])
# increasing
# 2007-06-11, Close, 17.09
# array('d', [16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09])
# no trend
# 2007-06-12, Close, 16.76
# array('d', [16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76])
# no trend
# 2007-06-13, Close, 17.17
# array('d', [16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17])
# no trend
# 2007-06-14, Close, 17.47
# array('d', [16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47])
# no trend
# 2007-06-14, SELL CREATE, 17.47
# 2007-06-15, SELL EXECUTED, Price: 17.71, Cost: 166.60, Comm 0.00
# 2007-06-15, OPERATION PROFIT, GROSS 10.50, NET 10.50
# 2007-06-15, Close, 17.67
# array('d', [17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67])
# no trend
# 2007-06-18, Close, 17.60
# array('d', [17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6])
# no trend
# 2007-06-19, Close, 17.68
# array('d', [17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68])
# no trend
# 2007-06-20, Close, 17.37
# array('d', [17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37])
# increasing
# 2007-06-21, Close, 17.51
# array('d', [16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51])
# increasing
# 2007-06-22, Close, 17.25
# array('d', [17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25])
# no trend
# 2007-06-25, Close, 17.33
# array('d', [17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33])
# no trend
# 2007-06-26, Close, 17.04
# array('d', [17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04])
# no trend
# 2007-06-26, BUY CREATE, 17.04
# 2007-06-27, BUY EXECUTED, Price: 17.18, Cost: 171.80, Comm 0.00
# 2007-06-27, Close, 17.51
# array('d', [17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51])
# no trend
# 2007-06-27, SELL CREATE, 17.51
# 2007-06-28, SELL EXECUTED, Price: 17.45, Cost: 171.80, Comm 0.00
# 2007-06-28, OPERATION PROFIT, GROSS 2.70, NET 2.70
# 2007-06-28, Close, 17.66
# array('d', [17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66])
# no trend
# 2007-06-29, Close, 17.53
# array('d', [17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53])
# no trend
# 2007-07-02, Close, 17.72
# array('d', [17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72])
# increasing
# 2007-07-03, Close, 17.85
# array('d', [17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85])
# increasing
# 2007-07-05, Close, 18.23
# array('d', [16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23])
# increasing
# 2007-07-06, Close, 18.15
# array('d', [16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15])
# increasing
# 2007-07-09, Close, 17.93
# array('d', [17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93])
# increasing
# 2007-07-10, Close, 17.54
# array('d', [16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54])
# increasing
# 2007-07-11, Close, 17.77
# array('d', [17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77])
# increasing
# 2007-07-12, Close, 18.23
# array('d', [17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23])
# increasing
# 2007-07-13, Close, 18.15
# array('d', [17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15])
# increasing
# 2007-07-16, Close, 17.97
# array('d', [17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97])
# increasing
# 2007-07-17, Close, 18.13
# array('d', [17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13])
# increasing
# 2007-07-18, Close, 18.15
# array('d', [17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15])
# increasing
# 2007-07-19, Close, 18.32
# array('d', [17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32])
# increasing
# 2007-07-20, Close, 18.33
# array('d', [17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33])
# increasing
# 2007-07-23, Close, 18.48
# array('d', [17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48])
# increasing
# 2007-07-24, Close, 18.36
# array('d', [17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36])
# increasing
# 2007-07-25, Close, 18.31
# array('d', [17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31])
# increasing
# 2007-07-26, Close, 17.80
# array('d', [17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8])
# increasing
# 2007-07-26, BUY CREATE, 17.80
# 2007-07-27, BUY EXECUTED, Price: 17.79, Cost: 177.90, Comm 0.00
# 2007-07-27, Close, 17.45
# array('d', [17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45])
# increasing
# 2007-07-30, Close, 17.42
# array('d', [17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42])
# no trend
# 2007-07-31, Close, 17.01
# array('d', [17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01])
# no trend
# 2007-08-01, Close, 17.60
# array('d', [18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6])
# no trend
# 2007-08-02, Close, 17.87
# array('d', [18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87])
# no trend
# 2007-08-03, Close, 17.49
# array('d', [17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49])
# no trend
# 2007-08-06, Close, 17.86
# array('d', [17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86])
# no trend
# 2007-08-07, Close, 17.51
# array('d', [17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51])
# no trend
# 2007-08-08, Close, 17.97
# array('d', [18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97])
# decreasing
# 2007-08-09, Close, 17.87
# array('d', [18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87])
# no trend
# 2007-08-10, Close, 17.78
# array('d', [17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78])
# no trend
# 2007-08-13, Close, 17.54
# array('d', [18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54])
# no trend
# 2007-08-14, Close, 17.21
# array('d', [18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21])
# decreasing
# 2007-08-15, Close, 17.06
# array('d', [18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06])
# decreasing
# 2007-08-16, Close, 17.02
# array('d', [18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02])
# decreasing
# 2007-08-17, Close, 17.21
# array('d', [18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21])
# decreasing
# 2007-08-20, Close, 17.00
# array('d', [18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0])
# decreasing
# 2007-08-21, Close, 17.14
# array('d', [18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14])
# decreasing
# 2007-08-22, Close, 17.18
# array('d', [17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18])
# no trend
# 2007-08-23, Close, 17.23
# array('d', [17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23])
# no trend
# 2007-08-24, Close, 17.74
# array('d', [17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74])
# no trend
# 2007-08-24, SELL CREATE, 17.74
# 2007-08-27, SELL EXECUTED, Price: 17.75, Cost: 177.90, Comm 0.00
# 2007-08-27, OPERATION PROFIT, GROSS -0.40, NET -0.40
# 2007-08-27, Close, 17.67
# array('d', [17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67])
# no trend
# 2007-08-28, Close, 17.22
# array('d', [17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22])
# no trend
# 2007-08-28, BUY CREATE, 17.22
# 2007-08-29, BUY EXECUTED, Price: 17.27, Cost: 172.70, Comm 0.00
# 2007-08-29, Close, 17.91
# array('d', [17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91])
# no trend
# 2007-08-29, SELL CREATE, 17.91
# 2007-08-30, SELL EXECUTED, Price: 17.75, Cost: 172.70, Comm 0.00
# 2007-08-30, OPERATION PROFIT, GROSS 4.80, NET 4.80
# 2007-08-30, Close, 17.98
# array('d', [17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98])
# no trend
# 2007-08-31, Close, 18.04
# array('d', [17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04])
# no trend
# 2007-09-04, Close, 18.43
# array('d', [17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43])
# no trend
# 2007-09-05, Close, 18.44
# array('d', [17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44])
# no trend
# 2007-09-06, Close, 18.27
# array('d', [17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27])
# increasing
# 2007-09-07, Close, 17.93
# array('d', [17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93])
# increasing
# 2007-09-10, Close, 17.94
# array('d', [17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94])
# increasing
# 2007-09-11, Close, 18.20
# array('d', [17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2])
# increasing
# 2007-09-12, Close, 18.27
# array('d', [17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27])
# increasing
# 2007-09-13, Close, 18.19
# array('d', [17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19])
# increasing
# 2007-09-14, Close, 17.85
# array('d', [17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85])
# increasing
# 2007-09-17, Close, 17.81
# array('d', [17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81])
# increasing
# 2007-09-18, Close, 18.44
# array('d', [17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44])
# increasing
# 2007-09-19, Close, 18.54
# array('d', [17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54])
# increasing
# 2007-09-20, Close, 18.71
# array('d', [17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71])
# increasing
# 2007-09-21, Close, 19.55
# array('d', [17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55])
# increasing
# 2007-09-24, Close, 19.38
# array('d', [17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38])
# increasing
# 2007-09-25, Close, 19.52
# array('d', [17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52])
# increasing
# 2007-09-26, Close, 19.36
# array('d', [17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36])
# increasing
# 2007-09-27, Close, 19.24
# array('d', [17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24])
# increasing
# 2007-09-28, Close, 19.26
# array('d', [18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26])
# increasing
# 2007-10-01, Close, 19.54
# array('d', [18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54])
# increasing
# 2007-10-02, Close, 19.44
# array('d', [18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44])
# increasing
# 2007-10-03, Close, 19.19
# array('d', [18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19])
# increasing
# 2007-10-04, Close, 19.36
# array('d', [17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36])
# increasing
# 2007-10-05, Close, 19.73
# array('d', [17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73])
# increasing
# 2007-10-08, Close, 20.02
# array('d', [18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02])
# increasing
# 2007-10-09, Close, 20.08
# array('d', [18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08])
# increasing
# 2007-10-10, Close, 20.39
# array('d', [18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39])
# increasing
# 2007-10-11, Close, 19.98
# array('d', [17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98])
# increasing
# 2007-10-12, Close, 19.96
# array('d', [17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96])
# increasing
# 2007-10-15, Close, 19.63
# array('d', [18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63])
# increasing
# 2007-10-16, Close, 19.35
# array('d', [18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35])
# increasing
# 2007-10-17, Close, 19.12
# array('d', [18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12])
# no trend
# 2007-10-17, BUY CREATE, 19.12
# 2007-10-18, BUY EXECUTED, Price: 19.12, Cost: 191.20, Comm 0.00
# 2007-10-18, Close, 19.06
# array('d', [19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06])
# no trend
# 2007-10-19, Close, 18.46
# array('d', [19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46])
# no trend
# 2007-10-22, Close, 18.86
# array('d', [19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86])
# no trend
# 2007-10-23, Close, 19.08
# array('d', [19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08])
# no trend
# 2007-10-24, Close, 18.84
# array('d', [19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84])
# no trend
# 2007-10-25, Close, 18.68
# array('d', [19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68])
# decreasing
# 2007-10-26, Close, 18.99
# array('d', [19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99])
# decreasing
# 2007-10-29, Close, 19.36
# array('d', [19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36])
# decreasing
# 2007-10-30, Close, 19.24
# array('d', [19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24])
# decreasing
# 2007-10-31, Close, 19.72
# array('d', [19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72])
# decreasing
# 2007-10-31, SELL CREATE, 19.72
# 2007-11-01, SELL EXECUTED, Price: 19.57, Cost: 191.20, Comm 0.00
# 2007-11-01, OPERATION PROFIT, GROSS 4.50, NET 4.50
# 2007-11-01, Close, 19.36
# array('d', [19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36])
# decreasing
# 2007-11-02, Close, 19.60
# array('d', [20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6])
# no trend
# 2007-11-05, Close, 19.63
# array('d', [20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63])
# no trend
# 2007-11-06, Close, 20.31
# array('d', [20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31])
# no trend
# 2007-11-07, Close, 19.66
# array('d', [19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66])
# no trend
# 2007-11-08, Close, 18.10
# array('d', [19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1])
# no trend
# 2007-11-08, BUY CREATE, 18.10
# 2007-11-09, BUY EXECUTED, Price: 17.73, Cost: 177.30, Comm 0.00
# 2007-11-09, Close, 17.22
# array('d', [19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22])
# no trend
# 2007-11-12, Close, 17.29
# array('d', [19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29])
# no trend
# 2007-11-13, Close, 18.25
# array('d', [19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25])
# no trend
# 2007-11-14, Close, 17.95
# array('d', [19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95])
# no trend
# 2007-11-15, Close, 18.16
# array('d', [18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16])
# no trend
# 2007-11-16, Close, 18.50
# array('d', [18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5])
# no trend
# 2007-11-19, Close, 18.26
# array('d', [19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26])
# no trend
# 2007-11-20, Close, 18.40
# array('d', [18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4])
# no trend
# 2007-11-21, Close, 17.98
# array('d', [18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98])
# no trend
# 2007-11-23, Close, 18.07
# array('d', [18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07])
# no trend
# 2007-11-26, Close, 17.52
# array('d', [19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52])
# decreasing
# 2007-11-27, Close, 17.69
# array('d', [19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69])
# decreasing
# 2007-11-28, Close, 18.24
# array('d', [19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24])
# decreasing
# 2007-11-29, Close, 18.22
# array('d', [19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22])
# no trend
# 2007-11-30, Close, 17.95
# array('d', [19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95])
# no trend
# 2007-12-03, Close, 18.00
# array('d', [19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0])
# no trend
# 2007-12-04, Close, 17.82
# array('d', [20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82])
# no trend
# 2007-12-05, Close, 18.87
# array('d', [19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87])
# no trend
# 2007-12-05, SELL CREATE, 18.87
# 2007-12-06, SELL EXECUTED, Price: 18.77, Cost: 177.30, Comm 0.00
# 2007-12-06, OPERATION PROFIT, GROSS 10.40, NET 10.40
# 2007-12-06, Close, 19.05
# array('d', [18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05])
# no trend
# 2007-12-07, Close, 18.80
# array('d', [17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8])
# no trend
# 2007-12-10, Close, 19.25
# array('d', [17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25])
# no trend
# 2007-12-11, Close, 18.74
# array('d', [18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74])
# no trend
# 2007-12-12, Close, 19.01
# array('d', [17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01])
# no trend
# 2007-12-13, Close, 19.22
# array('d', [18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22])
# increasing
# 2007-12-14, Close, 18.86
# array('d', [18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86])
# increasing
# 2007-12-17, Close, 18.63
# array('d', [18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63])
# increasing
# 2007-12-18, Close, 18.90
# array('d', [18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9])
# increasing
# 2007-12-19, Close, 18.47
# array('d', [17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47])
# increasing
# 2007-12-20, Close, 19.66
# array('d', [18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66])
# increasing
# 2007-12-21, Close, 20.20
# array('d', [17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2])
# increasing
# 2007-12-24, Close, 20.24
# array('d', [17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24])
# increasing
# 2007-12-26, Close, 20.46
# array('d', [18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46])
# increasing
# 2007-12-27, Close, 20.49
# array('d', [18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49])
# increasing
# 2007-12-28, Close, 20.43
# array('d', [17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49, 20.43])
# increasing
# 2007-12-31, Close, 20.08
# array('d', [18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49, 20.43, 20.08])
# increasing
# Final Portfolio Value: 1042.90
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 直接用均线策略

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import numpy as np
import pymannkendall as mk

# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),('trend_test_period', 20), ("period", 20), ("devfactor", 1), ("debug", False)
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.data_trend_test = self.datas[0].get(size=10)  # ago defaults to 0
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        #设置变点检验的区间
        #初始化布林线
        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)
        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])
        #进行趋势检验
        self.trend_test_data = self.data.get(size=self.params.trend_test_period)
        trend, h, p, z, Tau, s, var_s, slope, intercept = mk.original_test(self.trend_test_data)
        print(self.trend_test_data )
        print(trend)
        #直接用均线法则
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    modpath = os.path.dirname(os.path.abspath(sys.argv[1]))
    datapath = os.path.join(modpath, 'D:\desktop\orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        # Do not pass values before this date
        fromdate=datetime.datetime(2007, 1, 1),
        # Do not pass values before this date
        todate=datetime.datetime(2008, 1, 1),
        # Do not pass values after this date
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.plot(style='candlestick')
# Out:
# Starting Portfolio Value: 1000.00
# 2007-01-31, Close, 15.26
# array('d', [15.57, 15.73, 15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26])
# decreasing
# 2007-02-01, Close, 15.17
# array('d', [15.73, 15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17])
# decreasing
# 2007-02-02, Close, 15.49
# array('d', [15.69, 15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49])
# decreasing
# 2007-02-02, BUY CREATE, 15.49
# 2007-02-05, BUY EXECUTED, Price: 15.43, Cost: 154.30, Comm 0.00
# 2007-02-05, Close, 15.26
# array('d', [15.89, 15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26])
# decreasing
# 2007-02-05, SELL CREATE, 15.26
# 2007-02-06, SELL EXECUTED, Price: 15.24, Cost: 154.30, Comm 0.00
# 2007-02-06, OPERATION PROFIT, GROSS -1.90, NET -1.90
# 2007-02-06, Close, 15.14
# array('d', [15.85, 15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14])
# decreasing
# 2007-02-07, Close, 15.04
# array('d', [15.81, 15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04])
# decreasing
# 2007-02-08, Close, 14.86
# array('d', [15.47, 15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86])
# decreasing
# 2007-02-09, Close, 14.85
# array('d', [15.57, 15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85])
# decreasing
# 2007-02-12, Close, 14.81
# array('d', [15.39, 15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81])
# decreasing
# 2007-02-13, Close, 14.78
# array('d', [15.58, 15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78])
# decreasing
# 2007-02-14, Close, 14.92
# array('d', [15.23, 15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92])
# decreasing
# 2007-02-15, Close, 15.04
# array('d', [15.36, 15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04])
# decreasing
# 2007-02-16, Close, 14.85
# array('d', [15.12, 15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85])
# decreasing
# 2007-02-20, Close, 15.10
# array('d', [15.23, 15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1])
# decreasing
# 2007-02-20, BUY CREATE, 15.10
# 2007-02-21, BUY EXECUTED, Price: 15.09, Cost: 150.90, Comm 0.00
# 2007-02-21, Close, 15.30
# array('d', [15.25, 15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3])
# decreasing
# 2007-02-22, Close, 15.36
# array('d', [15.1, 15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36])
# no trend
# 2007-02-23, Close, 14.96
# array('d', [15.25, 15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96])
# no trend
# 2007-02-23, SELL CREATE, 14.96
# 2007-02-26, SELL EXECUTED, Price: 15.04, Cost: 150.90, Comm 0.00
# 2007-02-26, OPERATION PROFIT, GROSS -0.50, NET -0.50
# 2007-02-26, Close, 14.96
# array('d', [15.36, 15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96])
# no trend
# 2007-02-27, Close, 14.49
# array('d', [15.26, 15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49])
# no trend
# 2007-02-28, Close, 14.61
# array('d', [15.26, 15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61])
# decreasing
# 2007-03-01, Close, 14.92
# array('d', [15.17, 15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92])
# no trend
# 2007-03-02, Close, 14.86
# array('d', [15.49, 15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86])
# no trend
# 2007-03-05, Close, 14.56
# array('d', [15.26, 15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56])
# no trend
# 2007-03-06, Close, 15.01
# array('d', [15.14, 15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01])
# no trend
# 2007-03-06, BUY CREATE, 15.01
# 2007-03-07, BUY EXECUTED, Price: 14.92, Cost: 149.20, Comm 0.00
# 2007-03-07, Close, 14.67
# array('d', [15.04, 14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67])
# no trend
# 2007-03-07, SELL CREATE, 14.67
# 2007-03-08, SELL EXECUTED, Price: 14.85, Cost: 149.20, Comm 0.00
# 2007-03-08, OPERATION PROFIT, GROSS -0.70, NET -0.70
# 2007-03-08, Close, 14.85
# array('d', [14.86, 14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85])
# no trend
# 2007-03-09, Close, 14.79
# array('d', [14.85, 14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79])
# no trend
# 2007-03-12, Close, 15.18
# array('d', [14.81, 14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18])
# no trend
# 2007-03-12, BUY CREATE, 15.18
# 2007-03-13, BUY EXECUTED, Price: 15.06, Cost: 150.60, Comm 0.00
# 2007-03-13, Close, 14.81
# array('d', [14.78, 14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81])
# no trend
# 2007-03-13, SELL CREATE, 14.81
# 2007-03-14, SELL EXECUTED, Price: 14.89, Cost: 150.60, Comm 0.00
# 2007-03-14, OPERATION PROFIT, GROSS -1.70, NET -1.70
# 2007-03-14, Close, 15.01
# array('d', [14.92, 15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01])
# no trend
# 2007-03-14, BUY CREATE, 15.01
# 2007-03-15, BUY EXECUTED, Price: 14.99, Cost: 149.90, Comm 0.00
# 2007-03-15, Close, 14.87
# array('d', [15.04, 14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87])
# no trend
# 2007-03-16, Close, 14.85
# array('d', [14.85, 15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85])
# no trend
# 2007-03-19, Close, 15.28
# array('d', [15.1, 15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28])
# no trend
# 2007-03-20, Close, 15.61
# array('d', [15.3, 15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61])
# no trend
# 2007-03-21, Close, 16.16
# array('d', [15.36, 14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16])
# no trend
# 2007-03-22, Close, 16.45
# array('d', [14.96, 14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45])
# increasing
# 2007-03-23, Close, 16.22
# array('d', [14.96, 14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22])
# increasing
# 2007-03-26, Close, 16.36
# array('d', [14.49, 14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36])
# increasing
# 2007-03-27, Close, 16.45
# array('d', [14.61, 14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45])
# increasing
# 2007-03-28, Close, 16.16
# array('d', [14.92, 14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16])
# increasing
# 2007-03-29, Close, 16.15
# array('d', [14.86, 14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15])
# increasing
# 2007-03-30, Close, 16.13
# array('d', [14.56, 15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13])
# increasing
# 2007-04-02, Close, 16.14
# array('d', [15.01, 14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14])
# increasing
# 2007-04-03, Close, 16.33
# array('d', [14.67, 14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33])
# increasing
# 2007-04-04, Close, 16.51
# array('d', [14.85, 14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51])
# increasing
# 2007-04-05, Close, 16.61
# array('d', [14.79, 15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61])
# increasing
# 2007-04-09, Close, 16.52
# array('d', [15.18, 14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52])
# increasing
# 2007-04-10, Close, 16.77
# array('d', [14.81, 15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77])
# increasing
# 2007-04-11, Close, 16.54
# array('d', [15.01, 14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54])
# increasing
# 2007-04-12, Close, 16.63
# array('d', [14.87, 14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63])
# increasing
# 2007-04-13, Close, 16.57
# array('d', [14.85, 15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57])
# increasing
# 2007-04-16, Close, 16.81
# array('d', [15.28, 15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81])
# increasing
# 2007-04-17, Close, 16.80
# array('d', [15.61, 16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8])
# increasing
# 2007-04-18, Close, 16.66
# array('d', [16.16, 16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66])
# increasing
# 2007-04-19, Close, 16.69
# array('d', [16.45, 16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69])
# increasing
# 2007-04-20, Close, 16.90
# array('d', [16.22, 16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9])
# increasing
# 2007-04-23, Close, 16.85
# array('d', [16.36, 16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85])
# increasing
# 2007-04-24, Close, 16.74
# array('d', [16.45, 16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74])
# increasing
# 2007-04-25, Close, 16.81
# array('d', [16.16, 16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81])
# increasing
# 2007-04-26, Close, 16.86
# array('d', [16.15, 16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86])
# increasing
# 2007-04-27, Close, 16.99
# array('d', [16.13, 16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99])
# increasing
# 2007-04-30, Close, 16.72
# array('d', [16.14, 16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72])
# increasing
# 2007-04-30, SELL CREATE, 16.72
# 2007-05-01, SELL EXECUTED, Price: 16.68, Cost: 149.90, Comm 0.00
# 2007-05-01, OPERATION PROFIT, GROSS 16.90, NET 16.90
# 2007-05-01, Close, 16.54
# array('d', [16.33, 16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54])
# increasing
# 2007-05-02, Close, 16.78
# array('d', [16.51, 16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78])
# increasing
# 2007-05-02, BUY CREATE, 16.78
# 2007-05-03, BUY EXECUTED, Price: 16.82, Cost: 168.20, Comm 0.00
# 2007-05-03, Close, 16.92
# array('d', [16.61, 16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92])
# increasing
# 2007-05-04, Close, 16.93
# array('d', [16.52, 16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93])
# increasing
# 2007-05-07, Close, 16.94
# array('d', [16.77, 16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94])
# increasing
# 2007-05-08, Close, 16.86
# array('d', [16.54, 16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86])
# increasing
# 2007-05-09, Close, 16.75
# array('d', [16.63, 16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75])
# increasing
# 2007-05-09, SELL CREATE, 16.75
# 2007-05-10, SELL EXECUTED, Price: 16.62, Cost: 168.20, Comm 0.00
# 2007-05-10, OPERATION PROFIT, GROSS -2.00, NET -2.00
# 2007-05-10, Close, 16.45
# array('d', [16.57, 16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45])
# no trend
# 2007-05-11, Close, 16.88
# array('d', [16.81, 16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88])
# no trend
# 2007-05-11, BUY CREATE, 16.88
# 2007-05-14, BUY EXECUTED, Price: 16.85, Cost: 168.50, Comm 0.00
# 2007-05-14, Close, 16.85
# array('d', [16.8, 16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85])
# no trend
# 2007-05-15, Close, 16.76
# array('d', [16.66, 16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76])
# no trend
# 2007-05-15, SELL CREATE, 16.76
# 2007-05-16, SELL EXECUTED, Price: 16.78, Cost: 168.50, Comm 0.00
# 2007-05-16, OPERATION PROFIT, GROSS -0.70, NET -0.70
# 2007-05-16, Close, 16.89
# array('d', [16.69, 16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89])
# no trend
# 2007-05-16, BUY CREATE, 16.89
# 2007-05-17, BUY EXECUTED, Price: 16.78, Cost: 167.80, Comm 0.00
# 2007-05-17, Close, 16.94
# array('d', [16.9, 16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94])
# no trend
# 2007-05-18, Close, 17.12
# array('d', [16.85, 16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12])
# no trend
# 2007-05-21, Close, 17.18
# array('d', [16.74, 16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18])
# no trend
# 2007-05-22, Close, 17.23
# array('d', [16.81, 16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23])
# increasing
# 2007-05-23, Close, 17.04
# array('d', [16.86, 16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04])
# increasing
# 2007-05-24, Close, 16.68
# array('d', [16.99, 16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68])
# no trend
# 2007-05-24, SELL CREATE, 16.68
# 2007-05-25, SELL EXECUTED, Price: 16.80, Cost: 167.80, Comm 0.00
# 2007-05-25, OPERATION PROFIT, GROSS 0.20, NET 0.20
# 2007-05-25, Close, 17.11
# array('d', [16.72, 16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11])
# increasing
# 2007-05-25, BUY CREATE, 17.11
# 2007-05-29, BUY EXECUTED, Price: 17.16, Cost: 171.60, Comm 0.00
# 2007-05-29, Close, 17.18
# array('d', [16.54, 16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18])
# increasing
# 2007-05-30, Close, 17.27
# array('d', [16.78, 16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27])
# increasing
# 2007-05-31, Close, 17.24
# array('d', [16.92, 16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24])
# increasing
# 2007-06-01, Close, 17.49
# array('d', [16.93, 16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49])
# increasing
# 2007-06-04, Close, 17.50
# array('d', [16.94, 16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5])
# increasing
# 2007-06-05, Close, 17.33
# array('d', [16.86, 16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33])
# increasing
# 2007-06-06, Close, 17.21
# array('d', [16.75, 16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21])
# increasing
# 2007-06-07, Close, 16.66
# array('d', [16.45, 16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66])
# increasing
# 2007-06-07, SELL CREATE, 16.66
# 2007-06-08, SELL EXECUTED, Price: 16.66, Cost: 171.60, Comm 0.00
# 2007-06-08, OPERATION PROFIT, GROSS -5.00, NET -5.00
# 2007-06-08, Close, 16.95
# array('d', [16.88, 16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95])
# increasing
# 2007-06-11, Close, 17.09
# array('d', [16.85, 16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09])
# no trend
# 2007-06-12, Close, 16.76
# array('d', [16.76, 16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76])
# no trend
# 2007-06-13, Close, 17.17
# array('d', [16.89, 16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17])
# no trend
# 2007-06-13, BUY CREATE, 17.17
# 2007-06-14, BUY EXECUTED, Price: 17.39, Cost: 173.90, Comm 0.00
# 2007-06-14, Close, 17.47
# array('d', [16.94, 17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47])
# no trend
# 2007-06-15, Close, 17.67
# array('d', [17.12, 17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67])
# no trend
# 2007-06-18, Close, 17.60
# array('d', [17.18, 17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6])
# no trend
# 2007-06-19, Close, 17.68
# array('d', [17.23, 17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68])
# no trend
# 2007-06-20, Close, 17.37
# array('d', [17.04, 16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37])
# increasing
# 2007-06-21, Close, 17.51
# array('d', [16.68, 17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51])
# increasing
# 2007-06-22, Close, 17.25
# array('d', [17.11, 17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25])
# no trend
# 2007-06-22, SELL CREATE, 17.25
# 2007-06-25, SELL EXECUTED, Price: 17.30, Cost: 173.90, Comm 0.00
# 2007-06-25, OPERATION PROFIT, GROSS -0.90, NET -0.90
# 2007-06-25, Close, 17.33
# array('d', [17.18, 17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33])
# no trend
# 2007-06-25, BUY CREATE, 17.33
# 2007-06-26, BUY EXECUTED, Price: 17.45, Cost: 174.50, Comm 0.00
# 2007-06-26, Close, 17.04
# array('d', [17.27, 17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04])
# no trend
# 2007-06-26, SELL CREATE, 17.04
# 2007-06-27, SELL EXECUTED, Price: 17.18, Cost: 174.50, Comm 0.00
# 2007-06-27, OPERATION PROFIT, GROSS -2.70, NET -2.70
# 2007-06-27, Close, 17.51
# array('d', [17.24, 17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51])
# no trend
# 2007-06-27, BUY CREATE, 17.51
# 2007-06-28, BUY EXECUTED, Price: 17.45, Cost: 174.50, Comm 0.00
# 2007-06-28, Close, 17.66
# array('d', [17.49, 17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66])
# no trend
# 2007-06-29, Close, 17.53
# array('d', [17.5, 17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53])
# no trend
# 2007-07-02, Close, 17.72
# array('d', [17.33, 17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72])
# increasing
# 2007-07-03, Close, 17.85
# array('d', [17.21, 16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85])
# increasing
# 2007-07-05, Close, 18.23
# array('d', [16.66, 16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23])
# increasing
# 2007-07-06, Close, 18.15
# array('d', [16.95, 17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15])
# increasing
# 2007-07-09, Close, 17.93
# array('d', [17.09, 16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93])
# increasing
# 2007-07-10, Close, 17.54
# array('d', [16.76, 17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54])
# increasing
# 2007-07-10, SELL CREATE, 17.54
# 2007-07-11, SELL EXECUTED, Price: 17.59, Cost: 174.50, Comm 0.00
# 2007-07-11, OPERATION PROFIT, GROSS 1.40, NET 1.40
# 2007-07-11, Close, 17.77
# array('d', [17.17, 17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77])
# increasing
# 2007-07-11, BUY CREATE, 17.77
# 2007-07-12, BUY EXECUTED, Price: 17.83, Cost: 178.30, Comm 0.00
# 2007-07-12, Close, 18.23
# array('d', [17.47, 17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23])
# increasing
# 2007-07-13, Close, 18.15
# array('d', [17.67, 17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15])
# increasing
# 2007-07-16, Close, 17.97
# array('d', [17.6, 17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97])
# increasing
# 2007-07-17, Close, 18.13
# array('d', [17.68, 17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13])
# increasing
# 2007-07-18, Close, 18.15
# array('d', [17.37, 17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15])
# increasing
# 2007-07-19, Close, 18.32
# array('d', [17.51, 17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32])
# increasing
# 2007-07-20, Close, 18.33
# array('d', [17.25, 17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33])
# increasing
# 2007-07-23, Close, 18.48
# array('d', [17.33, 17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48])
# increasing
# 2007-07-24, Close, 18.36
# array('d', [17.04, 17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36])
# increasing
# 2007-07-25, Close, 18.31
# array('d', [17.51, 17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31])
# increasing
# 2007-07-26, Close, 17.80
# array('d', [17.66, 17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8])
# increasing
# 2007-07-26, SELL CREATE, 17.80
# 2007-07-27, SELL EXECUTED, Price: 17.79, Cost: 178.30, Comm 0.00
# 2007-07-27, OPERATION PROFIT, GROSS -0.40, NET -0.40
# 2007-07-27, Close, 17.45
# array('d', [17.53, 17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45])
# increasing
# 2007-07-30, Close, 17.42
# array('d', [17.72, 17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42])
# no trend
# 2007-07-31, Close, 17.01
# array('d', [17.85, 18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01])
# no trend
# 2007-08-01, Close, 17.60
# array('d', [18.23, 18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6])
# no trend
# 2007-08-02, Close, 17.87
# array('d', [18.15, 17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87])
# no trend
# 2007-08-03, Close, 17.49
# array('d', [17.93, 17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49])
# no trend
# 2007-08-06, Close, 17.86
# array('d', [17.54, 17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86])
# no trend
# 2007-08-07, Close, 17.51
# array('d', [17.77, 18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51])
# no trend
# 2007-08-08, Close, 17.97
# array('d', [18.23, 18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97])
# decreasing
# 2007-08-08, BUY CREATE, 17.97
# 2007-08-09, BUY EXECUTED, Price: 17.74, Cost: 177.40, Comm 0.00
# 2007-08-09, Close, 17.87
# array('d', [18.15, 17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87])
# no trend
# 2007-08-10, Close, 17.78
# array('d', [17.97, 18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78])
# no trend
# 2007-08-10, SELL CREATE, 17.78
# 2007-08-13, SELL EXECUTED, Price: 17.73, Cost: 177.40, Comm 0.00
# 2007-08-13, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2007-08-13, Close, 17.54
# array('d', [18.13, 18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54])
# no trend
# 2007-08-14, Close, 17.21
# array('d', [18.15, 18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21])
# decreasing
# 2007-08-15, Close, 17.06
# array('d', [18.32, 18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06])
# decreasing
# 2007-08-16, Close, 17.02
# array('d', [18.33, 18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02])
# decreasing
# 2007-08-17, Close, 17.21
# array('d', [18.48, 18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21])
# decreasing
# 2007-08-20, Close, 17.00
# array('d', [18.36, 18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0])
# decreasing
# 2007-08-21, Close, 17.14
# array('d', [18.31, 17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14])
# decreasing
# 2007-08-22, Close, 17.18
# array('d', [17.8, 17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18])
# no trend
# 2007-08-23, Close, 17.23
# array('d', [17.45, 17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23])
# no trend
# 2007-08-24, Close, 17.74
# array('d', [17.42, 17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74])
# no trend
# 2007-08-24, BUY CREATE, 17.74
# 2007-08-27, BUY EXECUTED, Price: 17.75, Cost: 177.50, Comm 0.00
# 2007-08-27, Close, 17.67
# array('d', [17.01, 17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67])
# no trend
# 2007-08-28, Close, 17.22
# array('d', [17.6, 17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22])
# no trend
# 2007-08-28, SELL CREATE, 17.22
# 2007-08-29, SELL EXECUTED, Price: 17.27, Cost: 177.50, Comm 0.00
# 2007-08-29, OPERATION PROFIT, GROSS -4.80, NET -4.80
# 2007-08-29, Close, 17.91
# array('d', [17.87, 17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91])
# no trend
# 2007-08-29, BUY CREATE, 17.91
# 2007-08-30, BUY EXECUTED, Price: 17.75, Cost: 177.50, Comm 0.00
# 2007-08-30, Close, 17.98
# array('d', [17.49, 17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98])
# no trend
# 2007-08-31, Close, 18.04
# array('d', [17.86, 17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04])
# no trend
# 2007-09-04, Close, 18.43
# array('d', [17.51, 17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43])
# no trend
# 2007-09-05, Close, 18.44
# array('d', [17.97, 17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44])
# no trend
# 2007-09-06, Close, 18.27
# array('d', [17.87, 17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27])
# increasing
# 2007-09-07, Close, 17.93
# array('d', [17.78, 17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93])
# increasing
# 2007-09-10, Close, 17.94
# array('d', [17.54, 17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94])
# increasing
# 2007-09-11, Close, 18.20
# array('d', [17.21, 17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2])
# increasing
# 2007-09-12, Close, 18.27
# array('d', [17.06, 17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27])
# increasing
# 2007-09-13, Close, 18.19
# array('d', [17.02, 17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19])
# increasing
# 2007-09-14, Close, 17.85
# array('d', [17.21, 17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85])
# increasing
# 2007-09-14, SELL CREATE, 17.85
# 2007-09-17, SELL EXECUTED, Price: 17.75, Cost: 177.50, Comm 0.00
# 2007-09-17, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2007-09-17, Close, 17.81
# array('d', [17.0, 17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81])
# increasing
# 2007-09-18, Close, 18.44
# array('d', [17.14, 17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44])
# increasing
# 2007-09-18, BUY CREATE, 18.44
# 2007-09-19, BUY EXECUTED, Price: 18.63, Cost: 186.30, Comm 0.00
# 2007-09-19, Close, 18.54
# array('d', [17.18, 17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54])
# increasing
# 2007-09-20, Close, 18.71
# array('d', [17.23, 17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71])
# increasing
# 2007-09-21, Close, 19.55
# array('d', [17.74, 17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55])
# increasing
# 2007-09-24, Close, 19.38
# array('d', [17.67, 17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38])
# increasing
# 2007-09-25, Close, 19.52
# array('d', [17.22, 17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52])
# increasing
# 2007-09-26, Close, 19.36
# array('d', [17.91, 17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36])
# increasing
# 2007-09-27, Close, 19.24
# array('d', [17.98, 18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24])
# increasing
# 2007-09-28, Close, 19.26
# array('d', [18.04, 18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26])
# increasing
# 2007-10-01, Close, 19.54
# array('d', [18.43, 18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54])
# increasing
# 2007-10-02, Close, 19.44
# array('d', [18.44, 18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44])
# increasing
# 2007-10-03, Close, 19.19
# array('d', [18.27, 17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19])
# increasing
# 2007-10-04, Close, 19.36
# array('d', [17.93, 17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36])
# increasing
# 2007-10-05, Close, 19.73
# array('d', [17.94, 18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73])
# increasing
# 2007-10-08, Close, 20.02
# array('d', [18.2, 18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02])
# increasing
# 2007-10-09, Close, 20.08
# array('d', [18.27, 18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08])
# increasing
# 2007-10-10, Close, 20.39
# array('d', [18.19, 17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39])
# increasing
# 2007-10-11, Close, 19.98
# array('d', [17.85, 17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98])
# increasing
# 2007-10-12, Close, 19.96
# array('d', [17.81, 18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96])
# increasing
# 2007-10-15, Close, 19.63
# array('d', [18.44, 18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63])
# increasing
# 2007-10-15, SELL CREATE, 19.63
# 2007-10-16, SELL EXECUTED, Price: 19.57, Cost: 186.30, Comm 0.00
# 2007-10-16, OPERATION PROFIT, GROSS 9.40, NET 9.40
# 2007-10-16, Close, 19.35
# array('d', [18.54, 18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35])
# increasing
# 2007-10-17, Close, 19.12
# array('d', [18.71, 19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12])
# no trend
# 2007-10-18, Close, 19.06
# array('d', [19.55, 19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06])
# no trend
# 2007-10-19, Close, 18.46
# array('d', [19.38, 19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46])
# no trend
# 2007-10-22, Close, 18.86
# array('d', [19.52, 19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86])
# no trend
# 2007-10-23, Close, 19.08
# array('d', [19.36, 19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08])
# no trend
# 2007-10-24, Close, 18.84
# array('d', [19.24, 19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84])
# no trend
# 2007-10-25, Close, 18.68
# array('d', [19.26, 19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68])
# decreasing
# 2007-10-26, Close, 18.99
# array('d', [19.54, 19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99])
# decreasing
# 2007-10-29, Close, 19.36
# array('d', [19.44, 19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36])
# decreasing
# 2007-10-29, BUY CREATE, 19.36
# 2007-10-30, BUY EXECUTED, Price: 19.26, Cost: 192.60, Comm 0.00
# 2007-10-30, Close, 19.24
# array('d', [19.19, 19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24])
# decreasing
# 2007-10-30, SELL CREATE, 19.24
# 2007-10-31, SELL EXECUTED, Price: 19.25, Cost: 192.60, Comm 0.00
# 2007-10-31, OPERATION PROFIT, GROSS -0.10, NET -0.10
# 2007-10-31, Close, 19.72
# array('d', [19.36, 19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72])
# decreasing
# 2007-10-31, BUY CREATE, 19.72
# 2007-11-01, BUY EXECUTED, Price: 19.57, Cost: 195.70, Comm 0.00
# 2007-11-01, Close, 19.36
# array('d', [19.73, 20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36])
# decreasing
# 2007-11-02, Close, 19.60
# array('d', [20.02, 20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6])
# no trend
# 2007-11-05, Close, 19.63
# array('d', [20.08, 20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63])
# no trend
# 2007-11-06, Close, 20.31
# array('d', [20.39, 19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31])
# no trend
# 2007-11-07, Close, 19.66
# array('d', [19.98, 19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66])
# no trend
# 2007-11-08, Close, 18.10
# array('d', [19.96, 19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1])
# no trend
# 2007-11-08, SELL CREATE, 18.10
# 2007-11-09, SELL EXECUTED, Price: 17.73, Cost: 195.70, Comm 0.00
# 2007-11-09, OPERATION PROFIT, GROSS -18.40, NET -18.40
# 2007-11-09, Close, 17.22
# array('d', [19.63, 19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22])
# no trend
# 2007-11-12, Close, 17.29
# array('d', [19.35, 19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29])
# no trend
# 2007-11-13, Close, 18.25
# array('d', [19.12, 19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25])
# no trend
# 2007-11-14, Close, 17.95
# array('d', [19.06, 18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95])
# no trend
# 2007-11-15, Close, 18.16
# array('d', [18.46, 18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16])
# no trend
# 2007-11-16, Close, 18.50
# array('d', [18.86, 19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5])
# no trend
# 2007-11-19, Close, 18.26
# array('d', [19.08, 18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26])
# no trend
# 2007-11-20, Close, 18.40
# array('d', [18.84, 18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4])
# no trend
# 2007-11-21, Close, 17.98
# array('d', [18.68, 18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98])
# no trend
# 2007-11-23, Close, 18.07
# array('d', [18.99, 19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07])
# no trend
# 2007-11-26, Close, 17.52
# array('d', [19.36, 19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52])
# decreasing
# 2007-11-27, Close, 17.69
# array('d', [19.24, 19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69])
# decreasing
# 2007-11-28, Close, 18.24
# array('d', [19.72, 19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24])
# decreasing
# 2007-11-28, BUY CREATE, 18.24
# 2007-11-29, BUY EXECUTED, Price: 18.22, Cost: 182.20, Comm 0.00
# 2007-11-29, Close, 18.22
# array('d', [19.36, 19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22])
# no trend
# 2007-11-30, Close, 17.95
# array('d', [19.6, 19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95])
# no trend
# 2007-11-30, SELL CREATE, 17.95
# 2007-12-03, SELL EXECUTED, Price: 17.99, Cost: 182.20, Comm 0.00
# 2007-12-03, OPERATION PROFIT, GROSS -2.30, NET -2.30
# 2007-12-03, Close, 18.00
# array('d', [19.63, 20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0])
# no trend
# 2007-12-04, Close, 17.82
# array('d', [20.31, 19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82])
# no trend
# 2007-12-05, Close, 18.87
# array('d', [19.66, 18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87])
# no trend
# 2007-12-05, BUY CREATE, 18.87
# 2007-12-06, BUY EXECUTED, Price: 18.77, Cost: 187.70, Comm 0.00
# 2007-12-06, Close, 19.05
# array('d', [18.1, 17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05])
# no trend
# 2007-12-07, Close, 18.80
# array('d', [17.22, 17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8])
# no trend
# 2007-12-10, Close, 19.25
# array('d', [17.29, 18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25])
# no trend
# 2007-12-11, Close, 18.74
# array('d', [18.25, 17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74])
# no trend
# 2007-12-12, Close, 19.01
# array('d', [17.95, 18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01])
# no trend
# 2007-12-13, Close, 19.22
# array('d', [18.16, 18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22])
# increasing
# 2007-12-14, Close, 18.86
# array('d', [18.5, 18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86])
# increasing
# 2007-12-17, Close, 18.63
# array('d', [18.26, 18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63])
# increasing
# 2007-12-18, Close, 18.90
# array('d', [18.4, 17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9])
# increasing
# 2007-12-19, Close, 18.47
# array('d', [17.98, 18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47])
# increasing
# 2007-12-19, SELL CREATE, 18.47
# 2007-12-20, SELL EXECUTED, Price: 19.95, Cost: 187.70, Comm 0.00
# 2007-12-20, OPERATION PROFIT, GROSS 11.80, NET 11.80
# 2007-12-20, Close, 19.66
# array('d', [18.07, 17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66])
# increasing
# 2007-12-20, BUY CREATE, 19.66
# 2007-12-21, BUY EXECUTED, Price: 19.84, Cost: 198.40, Comm 0.00
# 2007-12-21, Close, 20.20
# array('d', [17.52, 17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2])
# increasing
# 2007-12-24, Close, 20.24
# array('d', [17.69, 18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24])
# increasing
# 2007-12-26, Close, 20.46
# array('d', [18.24, 18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46])
# increasing
# 2007-12-27, Close, 20.49
# array('d', [18.22, 17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49])
# increasing
# 2007-12-28, Close, 20.43
# array('d', [17.95, 18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49, 20.43])
# increasing
# 2007-12-31, Close, 20.08
# array('d', [18.0, 17.82, 18.87, 19.05, 18.8, 19.25, 18.74, 19.01, 19.22, 18.86, 18.63, 18.9, 18.47, 19.66, 20.2, 20.24, 20.46, 20.49, 20.43, 20.08])
# increasing
# Final Portfolio Value: 999.90
# <img src="data:image/png;base64,..." width="640">
