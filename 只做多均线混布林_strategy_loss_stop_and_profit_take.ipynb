# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  
import os.path  
import sys  

# 导入backtrader
import backtrader as bt
import numpy as np
import pymannkendall as mk

# 创建策略
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15), ('trend_test_period', 30), ("period", 20), ("devfactor", 0.5), ("debug", False), ("size", 1),
        ("trail", False), ("stop_loss", 0.02), # price is 2% less than the entry point
        ("fast_ma", 10), ("slow_ma", 30),
        #止损率为sl 
        ('sl', 8.0),
        #止盈率是止损率的rr_ratio倍
        ('rr_ratio', 5),
        ('n', 5),
        ("flag", True) # flag == True多头,否则空头
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        #if self.params.printlog or doprint:
         #    dt = dt or self.datas[0].datetime.date(0)
          #   print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # 创建line对象，跟踪收盘价
        self.dataclose = self.datas[0].close
        #设置变点检验的区间
        self.data_trend_test = self.datas[0].get(size=self.p.trend_test_period)  # ago defaults to 0
        #初始化order变量
        self.order, self.sl_order, self.tp_order = None, None, None
        self.buyprice = None
        self.buycomm = None
        #
        #初始化布林线
        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)
        # omitting a data implies self.datas[0] (aka self.data and self.data0)
        self.fast_ma = bt.ind.EMA(period=self.p.fast_ma)
        self.slow_ma = bt.ind.EMA(period=self.p.slow_ma)
        # our entry point
        self.crossup = bt.ind.CrossDown(self.fast_ma, self.slow_ma)
       
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Order已经创建执行
            return

        # 钱不够的情况下Broker可以阻止order的创建
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f, Size %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            elif order.issell():  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f, Size %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm,
                          order.executed.size))
            

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        else:
            #交易关闭后取消sl_order和tp_order变量
            if self.sl_order:
                self.broker.cancel(self.sl_order)
                self.sl_order = None
                self.sl_price = 0.0

            if self.tp_order:
                self.broker.cancel(self.tp_order)
                self.tp_order = None
                self.tp_price = 0.0
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # 打印持仓信息
        print(self.position)
        #止损和利润确认
        if self.position:
            price_sl_long = self.position.price * (1 - self.p.sl / 100)
            price_sl_short = self.position.price * (1 + self.p.sl / 100)

            price_tp_long = self.position.price * (1 + self.p.sl / 100 * self.p.rr_ratio)
            price_tp_short = self.position.price * (1 - self.p.sl / 100 * self.p.rr_ratio)
            
            # cancel existing stop loss and take profit orders
            if self.sl_order:
                self.broker.cancel(self.sl_order)

            if self.tp_order:
                self.broker.cancel(self.tp_order)

            # check & update stop loss order
            self.sl_price = 0.0
            if self.position.size > 0 and price_sl_long !=0: self.sl_price = price_sl_long
            if self.position.size < 0 and price_sl_short !=0: self.sl_price = price_sl_short

            if self.sl_price != 0.0:
                self.sl_order = self.order_target_value(target=0.0, exectype=bt.Order.Stop,
                                                        price=self.sl_price)
            # check & update take profit order
            self.tp_price = 0.0
            if self.position.size > 0 and price_tp_long !=0: self.tp_price = price_tp_long
            if self.position.size < 0 and price_tp_short !=0: self.tp_price = price_tp_short

            if self.tp_price != 0.0:
                self.tp_order = self.order_target_value(target=0.0, exectype=bt.Order.Limit,
                                                        price=self.tp_price)
        #进行趋势检验
        self.trend_test_data = self.data.get(size=self.params.trend_test_period)
        trend, h, p, z, Tau, s, var_s, slope, intercept = mk.original_test(self.trend_test_data)
        print(trend)
        #没有趋势时，用布林线法则
        if trend == 'no trend':
            print('没有趋势,使用布林线法则')
            # 多头
            if self.p.flag:
                # 已开仓
                if self.position.size > 0: 
                    if self.dataclose[0] < self.boll.lines.bot:
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])
                        self.order = self.buy()
                #还没有持仓的情形
                elif self.position.size == 0:
                    if self.dataclose[0] < self.boll.lines.bot:
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])
                        self.order = self.buy()
                else:
                    print("已取消空头机制")
            # # 空头
            # else:
            #     # 已开仓
            #     if self.position.size < 0:
            #         if self.dataclose[0] > self.boll.lines.top:
            #             self.log('SELL CREATE, %.2f' % self.dataclose[0])
            #             self.order = self.sell() 
            #         elif self.dataclose[0] < self.boll.lines.bot:
            #             self.log('BUY CREATE, %.2f' % self.dataclose[0])
            #             self.order = self.buy()
            #         else:
            #             self.log('close short, %.2f' % self.dataclose[0])
            #             self.order = self.close()
            #     #还没有持仓的情形
            #     elif self.position.size == 0:
            #         if self.dataclose[0] > self.boll.lines.top:
            #             self.log('SELL CREATE, %.2f' % self.dataclose[0])
            #             self.order = self.sell() 
            #         else:
            #             self.log('close short, %.2f' % self.dataclose[0])
            #             self.order = self.close()
            #     else:
            #         print("wtf!!!")

        # 有趋势时，采用格兰维尔法则，实现买点1和卖点5
        else:  
            print('有趋势,使用均线法则')
            if self.order:
                return

            # 多头
            if self.p.flag: 
                # 已开仓
                if self.position.size > 0:
                    if self.dataclose[0] > self.fast_ma : # 金叉
                        print('BUY CREATE, %.2f' % self.dataclose[0])
                        self.order = self.buy()
                #还没有持仓的情形
                elif self.position.size == 0:
                    if self.dataclose[0] > self.fast_ma: # 金叉
                        print('BUY CREATE, %.2f' % self.dataclose[0])
                        self.order = self.buy()            
                else:
                    print("已取消空头机制")
                
            # 空头
            # else:
                # 已开仓
                # if self.position.size < 0:
                #     if self.dataclose[0] > self.fast_ma[0] and self.crossup > 0: # 金叉
                #         self.log('BUY CREATE, %.2f' % self.dataclose[0])
                #         self.order = self.buy(size=self.position.size)
                #     elif self.dataclose[0] < self.fast_ma[0] and self.crossup < 0: # 死叉
                #         self.log('SELL CREATE, %.2f' % self.dataclose[0])
                #         self.order = self.sell()
                #     else:
                #         self.log('close long, %.2f' % self.dataclose[0])
                #         self.order = self.close()
                # #还没有持仓的情形
                # elif self.position.size == 0:
                #     if self.dataclose[0] < self.fast_ma[0] and self.crossup < 0: # 死叉
                #         self.log('SELL CREATE, %.2f' % self.dataclose[0])
                #         self.order = self.sell()
                #     else:
                #         self.log('close long, %.2f' % self.dataclose[0])
                #         self.order = self.close()
                # else:
                #     print("wtf!!!")


if __name__ == '__main__':
    # 创建一个cerebro实体
    cerebro1 = bt.Cerebro() # 多头

    # 向实体中添加策略
    cerebro1.addstrategy(TestStrategy, flag=True) # 多头

    # 创建 Data Feed
    data = bt.feeds.GenericCSVData(
        dataname='D:\desktop\Maotai.csv',
        fromdate=datetime.datetime(2015, 1, 5),
        todate=datetime.datetime(2018, 1, 5),
        nullvalue=0.0,
        dtformat=('%Y-%m-%d'),
        datetime=0,
        open = 1,
        high = 2,
        low = 3,
        close = 4,
        volume =5, 
        openinterest=-1,
        reverse=False)

    # 在cerebro中添加数据
    cerebro1.adddata(data)

    # 设置初始现金值
    cerebro1.broker.setcash(100000.0)

    # 固定交易的手数
    cerebro1.addsizer(bt.sizers.FixedSize, stake=40)

    # 设置交易手续费
    cerebro1.broker.setcommission(commission=0.0)

    # 打印开始的金额
    print('Starting Portfolio Value: %.2f' % (cerebro1.broker.getvalue()))

    # 运行
    cerebro1.run()

    # 打印最终的金额
    # print('Final Portfolio Value: %.2f' % (cerebro1.broker.getvalue() + cerebro2.broker.getvalue()))
    print('1 Portfolio Value: %.2f' % cerebro1.broker.getvalue())
    cerebro1.plot(style='candlestick')
# Out:
# Starting Portfolio Value: 100000.00
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 0.0
# - Closed: 0
# - Opened: 0
# - Adjbase: None
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 183.31
# --- Position Begin
# - Size: 40
# - Price: 182.22
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 182.22
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 182.22
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 183.96
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 186.64
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 191.05
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 190.73
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 185.95
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 183.09
# - Price orig: 182.22
# - Closed: 0
# - Opened: 40
# - Adjbase: 187.19
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 187.19
# --- Position Begin
# - Size: 120
# - Price: 183.9
# - Price orig: 183.09
# - Closed: 0
# - Opened: 40
# - Adjbase: 185.52
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 120
# - Price: 183.9
# - Price orig: 183.09
# - Closed: 0
# - Opened: 40
# - Adjbase: 183.62
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 120
# - Price: 183.9
# - Price orig: 183.09
# - Closed: 0
# - Opened: 40
# - Adjbase: 191.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 191.56
# --- Position Begin
# - Size: 160
# - Price: 184.8825
# - Price orig: 183.9
# - Closed: 0
# - Opened: 40
# - Adjbase: 187.83
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 187.83
# --- Position Begin
# - Size: 200
# - Price: 186.30199999999996
# - Price orig: 184.8825
# - Closed: 0
# - Opened: 40
# - Adjbase: 191.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 191.98
# --- Position Begin
# - Size: 240
# - Price: 187.37666666666664
# - Price orig: 186.30199999999996
# - Closed: 0
# - Opened: 40
# - Adjbase: 192.75
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 192.75
# --- Position Begin
# - Size: 280
# - Price: 187.73857142857142
# - Price orig: 187.37666666666664
# - Closed: 0
# - Opened: 40
# - Adjbase: 189.91
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 189.91
# --- Position Begin
# - Size: 320
# - Price: 188.49124999999998
# - Price orig: 187.73857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 193.76
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 193.76
# --- Position Begin
# - Size: 360
# - Price: 189.4111111111111
# - Price orig: 188.49124999999998
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.77
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 196.77
# --- Position Begin
# - Size: 400
# - Price: 190.415
# - Price orig: 189.4111111111111
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.45
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 199.45
# --- Position Begin
# - Size: 440
# - Price: 190.85727272727271
# - Price orig: 190.415
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.28
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 195.28
# --- Position Begin
# - Size: 480
# - Price: 191.04833333333332
# - Price orig: 190.85727272727271
# - Closed: 0
# - Opened: 40
# - Adjbase: 193.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 193.15
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.08
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 195.08
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.69
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 195.69
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 192.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 198.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 198.56
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.55
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 194.55
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.77
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 196.77
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.96
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 195.96
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.34
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 195.34
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.58
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 196.81
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.67
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 200.67
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.5
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 204.50
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 200.00
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.22
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 200.22
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 203.9
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 203.90
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 206.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 206.00
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 205.7
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 205.70
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 226.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 226.27
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 232.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 232.56
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 234.03
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 234.03
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.43
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 257.43
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 263.89
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 263.89
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 256.04
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 256.04
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 258.49
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 258.49
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 255.79
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 255.79
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 247.89
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 247.89
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 249.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 249.78
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 252.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 252.23
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 254.97
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 254.97
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 240.95
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 242.68
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 244.93
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 254.17
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 254.17
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.44
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 257.44
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 254.42
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 254.42
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 256.4
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 256.40
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 251.41
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 251.41
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 245.17
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 241.14
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 250.04
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 250.04
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 253.95
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 253.95
# --- Position Begin
# - Size: 520
# - Price: 191.35846153846154
# - Price orig: 191.04833333333332
# - Closed: 0
# - Opened: 40
# - Adjbase: 258.59
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 258.59
# --- Position Begin
# - Size: 40
# - Price: 275.86
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 275.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 275.86
# --- Position Begin
# - Size: 80
# - Price: 281.34499999999997
# - Price orig: 275.86
# - Closed: 0
# - Opened: 40
# - Adjbase: 286.83
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 286.83
# --- Position Begin
# - Size: 120
# - Price: 282.7433333333333
# - Price orig: 281.34499999999997
# - Closed: 0
# - Opened: 40
# - Adjbase: 285.54
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 285.54
# --- Position Begin
# - Size: 160
# - Price: 281.28249999999997
# - Price orig: 282.7433333333333
# - Closed: 0
# - Opened: 40
# - Adjbase: 276.9
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 276.90
# --- Position Begin
# - Size: 200
# - Price: 277.248
# - Price orig: 281.28249999999997
# - Closed: 0
# - Opened: 40
# - Adjbase: 261.11
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 200
# - Price: 277.248
# - Price orig: 281.28249999999997
# - Closed: 0
# - Opened: 40
# - Adjbase: 263.83
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 200
# - Price: 277.248
# - Price orig: 281.28249999999997
# - Closed: 0
# - Opened: 40
# - Adjbase: 271.46
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 271.46
# --- Position Begin
# - Size: 240
# - Price: 275.47666666666663
# - Price orig: 277.248
# - Closed: 0
# - Opened: 40
# - Adjbase: 266.62
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 240
# - Price: 275.47666666666663
# - Price orig: 277.248
# - Closed: 0
# - Opened: 40
# - Adjbase: 262.79
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 240
# - Price: 275.47666666666663
# - Price orig: 277.248
# - Closed: 0
# - Opened: 40
# - Adjbase: 258.21
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 240
# - Price: 275.47666666666663
# - Price orig: 277.248
# - Closed: 0
# - Opened: 40
# - Adjbase: 253.84
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 240
# - Price: 275.47666666666663
# - Price orig: 277.248
# - Closed: 0
# - Opened: 40
# - Adjbase: 264.64
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 264.64
# --- Position Begin
# - Size: 280
# - Price: 273.1271428571428
# - Price orig: 275.47666666666663
# - Closed: 0
# - Opened: 40
# - Adjbase: 259.03
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 280
# - Price: 273.1271428571428
# - Price orig: 275.47666666666663
# - Closed: 0
# - Opened: 40
# - Adjbase: 261.05
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 280
# - Price: 273.1271428571428
# - Price orig: 275.47666666666663
# - Closed: 0
# - Opened: 40
# - Adjbase: 260.06
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 280
# - Price: 273.1271428571428
# - Price orig: 275.47666666666663
# - Closed: 0
# - Opened: 40
# - Adjbase: 266.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 266.00
# --- Position Begin
# - Size: 320
# - Price: 271.59749999999997
# - Price orig: 273.1271428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 260.89
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 320
# - Price: 271.59749999999997
# - Price orig: 273.1271428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 253.95
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 320
# - Price: 271.59749999999997
# - Price orig: 273.1271428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 255.09
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 40
# - Price: 243.97
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 243.97
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 80
# - Price: 239.63999999999996
# - Price orig: 243.97
# - Closed: 0
# - Opened: 40
# - Adjbase: 235.31
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 120
# - Price: 243.8433333333333
# - Price orig: 239.63999999999996
# - Closed: 0
# - Opened: 40
# - Adjbase: 252.25
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 160
# - Price: 248.185
# - Price orig: 243.8433333333333
# - Closed: 0
# - Opened: 40
# - Adjbase: 261.21
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 160
# - Price: 248.185
# - Price orig: 243.8433333333333
# - Closed: 0
# - Opened: 40
# - Adjbase: 251.79
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 200
# - Price: 247.03799999999998
# - Price orig: 248.185
# - Closed: 0
# - Opened: 40
# - Adjbase: 242.45
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 240
# - Price: 246.97166666666666
# - Price orig: 247.03799999999998
# - Closed: 0
# - Opened: 40
# - Adjbase: 246.64
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 240
# - Price: 246.97166666666666
# - Price orig: 247.03799999999998
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.65
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 257.65
# --- Position Begin
# - Size: 280
# - Price: 248.4742857142857
# - Price orig: 246.97166666666666
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.49
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 257.49
# --- Position Begin
# - Size: 320
# - Price: 249.95250000000001
# - Price orig: 248.4742857142857
# - Closed: 0
# - Opened: 40
# - Adjbase: 260.3
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 260.30
# --- Position Begin
# - Size: 360
# - Price: 249.93666666666667
# - Price orig: 249.95250000000001
# - Closed: 0
# - Opened: 40
# - Adjbase: 249.81
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 360
# - Price: 249.93666666666667
# - Price orig: 249.95250000000001
# - Closed: 0
# - Opened: 40
# - Adjbase: 254.04
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 254.04
# --- Position Begin
# - Size: 400
# - Price: 249.361
# - Price orig: 249.93666666666667
# - Closed: 0
# - Opened: 40
# - Adjbase: 244.18
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 400
# - Price: 249.361
# - Price orig: 249.93666666666667
# - Closed: 0
# - Opened: 40
# - Adjbase: 236.86
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 400
# - Price: 249.361
# - Price orig: 249.93666666666667
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.94
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 257.94
# --- Position Begin
# - Size: 440
# - Price: 250.83636363636364
# - Price orig: 249.361
# - Closed: 0
# - Opened: 40
# - Adjbase: 265.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 265.59
# --- Position Begin
# - Size: 480
# - Price: 251.4125
# - Price orig: 250.83636363636364
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.75
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 257.75
# --- Position Begin
# - Size: 520
# - Price: 251.23076923076923
# - Price orig: 251.4125
# - Closed: 0
# - Opened: 40
# - Adjbase: 249.05
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 251.23076923076923
# - Price orig: 251.4125
# - Closed: 0
# - Opened: 40
# - Adjbase: 251.26
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 520
# - Price: 251.23076923076923
# - Price orig: 251.4125
# - Closed: 0
# - Opened: 40
# - Adjbase: 251.59
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 251.23076923076923
# - Closed: -520
# - Opened: 0
# - Adjbase: 251.59
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 212.30
# --- Position Begin
# - Size: 40
# - Price: 210.75
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 210.75
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 210.75
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 209.47
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 209.51
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 209.98
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 206.22
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 201.06
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 201.62
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 80
# - Price: 210.10999999999999
# - Price orig: 210.75
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 210.10999999999999
# - Closed: -80
# - Opened: 0
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 210.10999999999999
# - Closed: -80
# - Opened: 0
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 210.10999999999999
# - Closed: -80
# - Opened: 0
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 210.10999999999999
# - Closed: -80
# - Opened: 0
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 0
# - Price: 0.0
# - Price orig: 210.10999999999999
# - Closed: -80
# - Opened: 0
# - Adjbase: 195.07
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 197.07
# --- Position Begin
# - Size: 40
# - Price: 192.65
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 192.65
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 192.65
# --- Position Begin
# - Size: 80
# - Price: 194.01
# - Price orig: 192.65
# - Closed: 0
# - Opened: 40
# - Adjbase: 195.37
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 195.37
# --- Position Begin
# - Size: 120
# - Price: 194.13
# - Price orig: 194.01
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.37
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 194.37
# --- Position Begin
# - Size: 160
# - Price: 194.25
# - Price orig: 194.13
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.61
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 194.61
# --- Position Begin
# - Size: 200
# - Price: 193.142
# - Price orig: 194.25
# - Closed: 0
# - Opened: 40
# - Adjbase: 188.71
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 200
# - Price: 193.142
# - Price orig: 194.25
# - Closed: 0
# - Opened: 40
# - Adjbase: 189.32
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 200
# - Price: 193.142
# - Price orig: 194.25
# - Closed: 0
# - Opened: 40
# - Adjbase: 191.86
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 191.86
# --- Position Begin
# - Size: 240
# - Price: 193.15333333333334
# - Price orig: 193.142
# - Closed: 0
# - Opened: 40
# - Adjbase: 193.21
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 193.21
# --- Position Begin
# - Size: 280
# - Price: 193.11857142857144
# - Price orig: 193.15333333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 192.91
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 192.91
# --- Position Begin
# - Size: 320
# - Price: 194.29500000000002
# - Price orig: 193.11857142857144
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.53
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 202.53
# --- Position Begin
# - Size: 360
# - Price: 195.15111111111113
# - Price orig: 194.29500000000002
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.0
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 202.00
# --- Position Begin
# - Size: 400
# - Price: 196.091
# - Price orig: 195.15111111111113
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.55
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 204.55
# --- Position Begin
# - Size: 440
# - Price: 196.26454545454547
# - Price orig: 196.091
# - Closed: 0
# - Opened: 40
# - Adjbase: 198.0
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 198.00
# --- Position Begin
# - Size: 480
# - Price: 196.52833333333334
# - Price orig: 196.26454545454547
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.43
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 199.43
# --- Position Begin
# - Size: 520
# - Price: 196.74153846153848
# - Price orig: 196.52833333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.3
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 520
# - Price: 196.74153846153848
# - Price orig: 196.52833333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.27
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 520
# - Price: 196.74153846153848
# - Price orig: 196.52833333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.72
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 520
# - Price: 196.74153846153848
# - Price orig: 196.52833333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 194.0
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 520
# - Price: 196.74153846153848
# - Price orig: 196.52833333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 193.46
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 196.35857142857142
# - Price orig: 196.74153846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 191.38
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 190.17
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 190.31
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 197.52
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.95
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 198.09
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 198.09
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 198.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 197.83
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.99
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.72
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 201.97
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 201.97
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.31
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 200.31
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.53
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 202.53
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 210.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 210.98
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 217.73
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 217.73
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 215.25
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 215.25
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.44
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 212.44
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 213.00
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 213.86
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 212.56
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 209.71
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 214.98
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 216.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 216.56
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 218.42
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 218.42
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 220.83
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 220.83
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 222.38
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 222.38
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 220.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 220.15
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 220.01
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 220.01
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 215.11
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.36
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 215.03
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.72
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.62
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 211.69
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.84
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 207.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.31
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.8
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 221.58
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 220.2
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 215.31
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.51
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 211.94
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.47
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.96
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 211.41
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.1
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 214.10
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.51
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 214.51
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 213.91
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 215.86
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 216.88
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 227.03
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 225.03
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 223.0
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 224.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 224.78
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 224.5
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 224.50
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 219.12
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 219.83
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 218.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 218.19
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 210.02
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.82
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.23
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.63
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.86
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.79
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.78
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.82
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.0
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.43
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 210.24
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 210.24
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.32
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.26
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.74
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.77
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.01
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 199.93
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 196.64
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.65
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 201.29
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 201.29
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.55
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 204.55
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 203.66
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 203.66
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 204.99
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 204.99
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 203.87
# --- Position End
# decreasing
# 有趋势,使用均线法则
# BUY CREATE, 203.87
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 200.41
# --- Position End
# decreasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 203.92
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 202.3
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 201.71
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 203.11
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 207.8
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.41
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 217.74
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 217.74
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 212.41
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 212.41
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 216.84
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 216.84
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 214.91
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 214.91
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 218.42
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 218.42
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 224.22
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 224.22
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 227.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 227.81
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 238.78
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 238.78
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 233.64
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 233.64
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 229.21
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 229.21
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 227.44
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 227.44
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 228.06
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 228.06
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 228.05
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 228.05
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 224.57
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 231.92
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 231.92
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 228.61
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 228.61
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 229.56
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 229.56
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 226.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 231.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 231.98
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 234.49
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 234.49
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 234.97
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 234.97
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 242.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 242.66
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 244.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 244.98
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 249.58
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 249.58
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 248.11
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 248.11
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 248.66
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 248.66
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 247.64
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 247.64
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 245.09
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 245.09
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 245.52
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 245.52
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# - Adjbase: 257.21
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 257.21
# --- Position Begin
# - Size: 600
# - Price: 195.946
# - Price orig: 196.35857142857142
# - Closed: 0
# - Opened: 40
# ...
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 492.81
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 492.81
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 492.99
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 492.99
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 492.04
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 492.04
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 489.44
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 492.97
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 492.97
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 491.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 495.18
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 495.18
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 492.42
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 492.42
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 489.99
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 484.98
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 481.27
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 474.37
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 478.32
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 484.91
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 491.63
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 490.71
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 489.84
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 498.97
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 496.95
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 496.2
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 498.77
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 499.93
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 507.24
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 509.29
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 508.21
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 508.21
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 518.46
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 518.46
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 517.64
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 517.64
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 527.77
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 527.77
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 540.06
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 540.06
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 545.54
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 545.54
# --- Position Begin
# - Size: 600
# - Price: 390.332
# - Price orig: 389.9421428571428
# - Closed: 0
# - Opened: 40
# - Adjbase: 544.09
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 544.09
# --- Position Begin
# - Size: 40
# - Price: 556.15
# - Price orig: 0.0
# - Closed: 0
# - Opened: 40
# - Adjbase: 556.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 556.15
# --- Position Begin
# - Size: 80
# - Price: 558.4200000000001
# - Price orig: 556.15
# - Closed: 0
# - Opened: 40
# - Adjbase: 560.69
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 560.69
# --- Position Begin
# - Size: 120
# - Price: 557.8566666666667
# - Price orig: 558.4200000000001
# - Closed: 0
# - Opened: 40
# - Adjbase: 556.73
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 556.73
# --- Position Begin
# - Size: 160
# - Price: 558.5725
# - Price orig: 557.8566666666667
# - Closed: 0
# - Opened: 40
# - Adjbase: 560.72
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 560.72
# --- Position Begin
# - Size: 200
# - Price: 563.378
# - Price orig: 558.5725
# - Closed: 0
# - Opened: 40
# - Adjbase: 582.6
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 582.60
# --- Position Begin
# - Size: 240
# - Price: 565.2033333333334
# - Price orig: 563.378
# - Closed: 0
# - Opened: 40
# - Adjbase: 574.33
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 574.33
# --- Position Begin
# - Size: 280
# - Price: 566.3757142857144
# - Price orig: 565.2033333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 573.41
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 573.41
# --- Position Begin
# - Size: 320
# - Price: 566.4950000000001
# - Price orig: 566.3757142857144
# - Closed: 0
# - Opened: 40
# - Adjbase: 567.33
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 567.33
# --- Position Begin
# - Size: 360
# - Price: 566.4033333333334
# - Price orig: 566.4950000000001
# - Closed: 0
# - Opened: 40
# - Adjbase: 565.67
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 565.67
# --- Position Begin
# - Size: 400
# - Price: 570.2720000000002
# - Price orig: 566.4033333333334
# - Closed: 0
# - Opened: 40
# - Adjbase: 605.09
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 605.09
# --- Position Begin
# - Size: 440
# - Price: 577.4863636363639
# - Price orig: 570.2720000000002
# - Closed: 0
# - Opened: 40
# - Adjbase: 649.63
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 649.63
# --- Position Begin
# - Size: 480
# - Price: 581.2025000000002
# - Price orig: 577.4863636363639
# - Closed: 0
# - Opened: 40
# - Adjbase: 622.08
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 622.08
# --- Position Begin
# - Size: 520
# - Price: 584.0353846153848
# - Price orig: 581.2025000000002
# - Closed: 0
# - Opened: 40
# - Adjbase: 618.03
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 618.03
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 623.01
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 623.01
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 626.92
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 626.92
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 639.17
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 639.17
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 653.06
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 653.06
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 642.07
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 642.07
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 650.38
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 650.38
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 650.07
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 650.07
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 677.95
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 677.95
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 687.88
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 687.88
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 678.75
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 678.75
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 688.08
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 688.08
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 719.11
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 719.11
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 690.25
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 690.25
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 679.15
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 679.15
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 677.25
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 677.25
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 650.52
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 633.73
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 630.04
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 621.29
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 648.23
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 638.12
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 631.0
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 622.35
# --- Position End
# increasing
# 有趋势,使用均线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 637.79
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 632.96
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 625.01
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 616.69
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 627.28
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 650.99
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 651.32
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 668.21
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 664.55
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 653.79
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 665.77
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 667.09
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 684.91
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 681.74
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 682.92
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 688.12
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 680.81
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 664.18
# --- Position End
# no trend
# 没有趋势,使用布林线法则
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 718.69
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 718.69
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 697.49
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 697.49
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 703.85
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 703.85
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 715.86
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 715.86
# --- Position Begin
# - Size: 560
# - Price: 586.819285714286
# - Price orig: 584.0353846153848
# - Closed: 0
# - Opened: 40
# - Adjbase: 737.07
# --- Position End
# increasing
# 有趋势,使用均线法则
# BUY CREATE, 737.07
# 1 Portfolio Value: 427557.60
# <img src="data:image/png;base64,..." width="639.9999861283738">
